# %% [markdown]
# ### Notebook Setup

# %%
#Import libraries

import pandas as pd
import numpy as np

import json
import requests # library to handle requests
from requests import get
import re # Regular expression
import ast

import matplotlib.pyplot as plt
import seaborn as sns

from itertools import islice
from geopy.geocoders import Nominatim

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

from bs4 import BeautifulSoup

# %%
pd.set_option('display.max_colwidth', None, 'display.max_rows', None)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ___

# %% [markdown]
# ### 1. Scrape data from online

# %%
#1.#https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%5E972&maxBedrooms=5&maxPrice=800000&minPrice=350000&index=24&propertyTypes=&includeSSTC=false&mustHave=&dontShow=newHome%2CsharedOwnership%2Cretirement&furnishTypes=&keywords=

#2#https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%5E94441&maxPrice=1000000&minPrice=300000&index=24&propertyTypes=detached%2Cflat%2Csemi-detached%2Cterraced&secondaryDisplayPropertyType=housesandflats&includeSSTC=false&mustHave=&dontShow=retirement&furnishTypes=&keywords=

#KT area: https://en.wikipedia.org/wiki/KT_postcode_area

all_data = pd.DataFrame([])

base_url= ("https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%5E94441&maxPrice=1000000&minPrice=300000&index=24&propertyTypes=detached%2Cflat%2Csemi-detached%2Cterraced&secondaryDisplayPropertyType=housesandflats&includeSSTC=false&mustHave=&dontShow=retirement&furnishTypes=&keywords=")

results = requests.get(base_url).text
soup = BeautifulSoup(results, "html.parser")

find = soup.find_all("script")

reg = r"window.jsonModel\s+=\s+(\{.*?\</script>)"

pattern = re.compile(reg)
match = pattern.findall(str(find))

match_strip = match[0].rstrip("</script>")

s1 = json.dumps(match_strip)
json_data = json.loads(s1) 

s3 = json.loads(str(json_data))

pagination =  s3.get("pagination").get("options")

pagination = pd.DataFrame(pagination)



for value in islice(pagination.iloc[:,0],0,42):
    print(value)

    iter_url = "https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%5E94441&maxPrice=1000000&minPrice=300000&index={}&propertyTypes=detached%2Cflat%2Csemi-detached%2Cterraced&secondaryDisplayPropertyType=housesandflats&includeSSTC=false&mustHave=&dontShow=retirement&furnishTypes=&keywords=".format(value)
    
   
   
    results = requests.get(iter_url).text
    soup = BeautifulSoup(results, "html.parser")
    
    find = soup.find_all("script")
    
    reg = r"window.jsonModel\s+=\s+(\{.*?\</script>)"

    pattern = re.compile(reg)
    match = pattern.findall(str(find))

    match_strip = match[0].rstrip("</script>")

    s1 = json.dumps(match_strip)
    json_data = json.loads(s1) 

    s3 = json.loads(str(json_data))
    
    list =  s3.get("properties")
    
    df = pd.DataFrame(list)
    df.drop(["propertyImages"], axis=1, inplace=True)

    all_data = all_data.append(df, ignore_index=True)
    
    
    
    
pd.set_option("display.max_rows", df.shape[0]+1)


all_data.shape
all_data
# Out:
# 0
# 24
# 48
# 72
# 96
# 120
# 144
# 168
# 192
# 216
# 240
# 264
# 288
# 312
# 336
# 360
# 384
# 408
# 432
# 456
# 480
# 504
# 528
# 552
# 576
# 600
# 624
# 648
# 672
# 696
# 720
# 744
# 768
# 792
# 816
# 840
# 864
# 888
# 912
# 936
# 960
# 984
# (1050, 47)
#              id  bedrooms  bathrooms  numberOfImages  numberOfFloorplans  \
# 0      89386117         4        3.0              19                   1
# 1      76636641         6        0.0              26                   1
# 2      86007409         4        2.0              12                   1
# 3      73255458         2        2.0              11                   1
# 4      88981993         4        2.0              14                   1
# ...         ...       ...        ...             ...                 ...
# 1045   96145934         3        1.0               9                   1
# 1046  102112697         3        NaN              14                   2
# 1047   99042143         3        2.0               9                   1
# 1048   87124249         3        1.0              17                   1
# 1049  101617700         3        NaN              14                   1
#
#       numberOfVirtualTours  \
# 0                        1
# 1                        1
# 2                        0
# 3                        1
# 4                        1
# ...                    ...
# 1045                     0
# 1046                     0
# 1047                     0
# 1048                     0
# 1049                     0
#
#                                                                                                                                                                                                                                                                                                          summary  \
# 0             Tucked away in an enclave of this peaceful residential cul-de-sac, this attractive and spacious terraced property is offered to the market in good condition and benefits from four/five bedrooms with flexible and well appointed accommodation. Built by an award winning developer and benef...
# 1            RARELY AVAILABLE DETACHED FAMILY HOME IN CUL-DE-SAC LOCATION CLOSE TO SCHOOLS AND STATION!!! Cairds are proud to bring to market for only the second time since new, this wonderful detached family home. Well loved and looked after for over 30 years, this substantial detached house is loca...
# 2                                                                                                                                                            Situated in a secluded position within close proximity of Hinchley Wood School and train station is this deceptively spacious detached family home!
# 3               A spectacular air conditioned two bedroom apartment located within an exclusive gated development in Esher with onsite concierge. Located on the second floor, the property briefly comprises a large hallway and open plan living/dining room, separate fitted kitchen, a principal suite co...
# 4         A newly constructed 4 bedroom detached house offering a delightful rear garden, excellent specification and situated in a popular semi rural location. Originally constructed in 2020 this beautifully presented home offers extremely light, bright and contemporary accommodation.  Currently thi...
# ...                                                                                                                                                                                                                                                                                                          ...
# 1045                                                                                                                                               This beautifully presented, three bedroom terrace family home benefits from an open plan kitchen diner leading, to a west facing, decked private rear garden.
# 1046                   The Thespian is a 3-bedroom home that features an open-plan kitchen and dining area, a separate living room, an en suite to bedroom 1 and a stylish family bathroom. *EXPRESS MOVER AVAILABLE - WE WILL HELP SELL YOUR HOME IN AS LITTLE AS 30 DAYS* *NO UPPER CHAIN* *MODERN THROUGHOUT*
# 1047                     ** WE ARE STILL OPEN PLEASE CALL FOR VIEWINGS AND VALUATIONS ** Barnard Marcus are pleased to welcome to the market this spacious three bedroom semi-detached family home. The property is situated within close proximity to Ewell Village and has fantastic potential to extend STPP.
# 1048  A well presented three bedroom family home situated in New Malden close to local amenities and excellent transport links. The property comprises of a large open plan living area combining the reception room with kitchen and dining area. The property also benefits from a private rear garden most...
# 1049                                                                                                      BEAT THE STAMP DUTY HOLIDAY ENDING ON THE 31ST MARCH. A three bedroom extended detached house in one of the most sought after roads in Chessington with no forward chain. Viewings highly recommended.
#
#                                    displayAddress countryCode  \
# 0                             Winter Close, Epsom          GB
# 1                            Boleyn Avenue, Epsom          GB
# 2                         Couchmore Avenue, Esher          GB
# 3       Broomhill Court, Esher Close, Esher, KT10          GB
# 4                                     Chessington          GB
# ...                                           ...         ...
# 1045                   Phyllis Avenue, New Malden          GB
# 1046  West Ewell,\r\nEwell,\r\nEpsom,\r\nKT19 9LN          GB
# 1047                           Ruxley Lane, Epsom          GB
# 1048                        Byron Ave, New Malden          GB
# 1049     Sherborne Road, Chessington, Surrey, KT9          GB
#
#                                              location  ...  \
# 0     {'latitude': 51.338951, 'longitude': -0.262866}  ...
# 1      {'latitude': 51.34777, 'longitude': -0.242032}  ...
# 2       {'latitude': 51.3791, 'longitude': -0.342057}  ...
# 3     {'latitude': 51.365766, 'longitude': -0.367829}  ...
# 4     {'latitude': 51.355801, 'longitude': -0.300656}  ...
# ...                                               ...  ...
# 1045  {'latitude': 51.398266, 'longitude': -0.234223}  ...
# 1046    {'latitude': 51.36223, 'longitude': -0.27247}  ...
# 1047  {'latitude': 51.364906, 'longitude': -0.268977}  ...
# 1048    {'latitude': 51.39715, 'longitude': -0.24427}  ...
# 1049    {'latitude': 51.36657, 'longitude': -0.30434}  ...
#
#      onlineViewingsAvailable displayStatus  \
# 0                      False
# 1                       True
# 2                       True
# 3                      False
# 4                      False
# ...                      ...           ...
# 1045                   False
# 1046                   False
# 1047                    True
# 1048                   False
# 1049                   False
#
#                               formattedBranchName         addedOrReduced  \
# 0                    by The Personal Agent, Epsom    Added on 26/02/2021
# 1      by Cairds The Estate Agents, Epsom - SALES  Reduced on 01/03/2021
# 2                     by Barnard Marcus, Surbiton    Added on 22/10/2020
# 3                     by Fine & Country, Richmond    Added on 15/09/2020
# 4        by Henshaws Estate Agents, Great Bookham    Added on 10/02/2021
# ...                                           ...                    ...
# 1045                by Barnard Marcus, New Malden  Reduced on 30/09/2020
# 1046              by Bellway Homes (South London)    Added on 19/01/2021
# 1047                     by Barnard Marcus, Ewell  Reduced on 29/12/2020
# 1048                   by Hunters, Worcester Park    Added on 26/11/2020
# 1049         by Compass Property Ltd, Chessington  Reduced on 30/01/2021
#
#      isRecent formattedDistance hasBrandPlus            heading  \
# 0       False                           True  Featured Property
# 1       False                           True
# 2       False                           True
# 3       False                           True
# 4       False                           True
# ...       ...               ...          ...                ...
# 1045    False                           True
# 1046    False                           True
# 1047    False                           True
# 1048    False                           True
# 1049    False                           True
#
#      enhancedListing              propertyTypeFullDescription
# 0              False        4 bedroom terraced house for sale
# 1              False        6 bedroom detached house for sale
# 2              False        4 bedroom detached house for sale
# 3              False             2 bedroom apartment for sale
# 4              False        4 bedroom detached house for sale
# ...              ...                                      ...
# 1045           False        3 bedroom terraced house for sale
# 1046           False        3 bedroom detached house for sale
# 1047           False   3 bedroom semi-detached house for sale
# 1048           False  3 bedroom end of terrace house for sale
# 1049           False        3 bedroom detached house for sale
#
# [1050 rows x 47 columns]

# %%
s3.get("properties")
# Out:
# [{'id': 89373922,
#   'bedrooms': 4,
#   'bathrooms': 3,
#   'numberOfImages': 43,
#   'numberOfFloorplans': 1,
#   'numberOfVirtualTours': 1,
#   'summary': 'Enjoying arguably the best position within a highly desirable gated development of just seven other detached family homes, this spacious and attractive property was built by Linden Homes in 2000 and has since been cleverly extended and updated by our clients who have created a truly stunning fami...',
#   'displayAddress': 'Woodlands Gardens, Epsom Downs',
#   'countryCode': 'GB',
#   'location': {'latitude': 51.315307, 'longitude': -0.233679},
#   'propertySubType': 'Detached',
#   'listingUpdate': {'listingUpdateReason': 'new',
#    'listingUpdateDate': '2021-02-26T09:38:01Z'},
#   'premiumListing': True,
#   'featuredProperty': True,
#   'price': {'amount': 1000000,
#    'frequency': 'not specified',
#    'currencyCode': 'GBP',
#    'displayPrices': [{'displayPrice': '£1,000,000',
#      'displayPriceQualifier': 'Offers Over'}]},
#   'customer': {'branchId': 10255,
#    'brandPlusLogoURI': '/11k/10255/branch_rmchoice_logo_10255_0000.png',
#    'contactTelephone': '01372 629132',
#    'branchDisplayName': 'The Personal Agent, Epsom',
#    'branchName': 'Epsom',
#    'brandTradingName': 'The Personal Agent',
#    'branchLandingPageUrl': '/estate-agents/agent/The-Personal-Agent/Epsom-10255.html',
#    'development': False,
#    'showReducedProperties': True,
#    'commercial': False,
#    'showOnMap': True,
#    'enhancedListing': False,
#    'developmentContent': None,
#    'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/11k/10255/branch_rmchoice_logo_10255_0000_max_100x50.png'},
#   'distance': None,
#   'transactionType': 'buy',
#   'productLabel': {'productLabelText': 'Media Tour', 'spotlightLabel': False},
#   'commercial': False,
#   'development': False,
#   'residential': True,
#   'students': False,
#   'auction': False,
#   'feesApply': False,
#   'feesApplyText': None,
#   'displaySize': '',
#   'showOnMap': True,
#   'propertyUrl': '/properties/89373922',
#   'contactUrl': '/property-for-sale/contactBranch.html?propertyId=89373922',
#   'staticMapUrl': None,
#   'channel': 'BUY',
#   'firstVisibleDate': '2021-02-26T09:32:39Z',
#   'keywords': [],
#   'keywordMatchType': 'no_keyword',
#   'saved': False,
#   'hidden': False,
#   'onlineViewingsAvailable': False,
#   'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_43_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_43_0000.jpeg',
#      'caption': '(Rightmove) 1-The Personal Agent 2-2.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_01_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_01_0000.jpeg',
#      'caption': '(Rightmove) 10.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_04_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_04_0000.jpeg',
#      'caption': '(Rightmove) 11.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_03_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_03_0000.jpeg',
#      'caption': '(Rightmove) 7.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_02_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_02_0000.jpeg',
#      'caption': '(Rightmove) 6.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_05_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_05_0000.jpeg',
#      'caption': '(Rightmove) 12.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_20_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_20_0000.jpeg',
#      'caption': '(Rightmove) 16.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_07_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_07_0000.jpeg',
#      'caption': '(Rightmove) 32.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_08_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_08_0000.jpeg',
#      'caption': '(Rightmove) 20.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_23_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_23_0000.jpeg',
#      'caption': '(Rightmove) 23.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_09_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_09_0000.jpeg',
#      'caption': '(Rightmove) 25.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_24_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_24_0000.jpeg',
#      'caption': '(Rightmove) 27.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_12_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_12_0000.jpeg',
#      'caption': '(Rightmove) 35.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_13_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_13_0000.jpeg',
#      'caption': '(Rightmove) 36.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_14_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_14_0000.jpeg',
#      'caption': '(Rightmove) 40.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_15_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_15_0000.jpeg',
#      'caption': '(Rightmove) 41.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_16_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_16_0000.jpeg',
#      'caption': '(Rightmove) 1.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_17_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_17_0000.jpeg',
#      'caption': '(Rightmove) 5.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_18_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_18_0000.jpeg',
#      'caption': '(Rightmove) 19.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_19_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_19_0000.jpeg',
#      'caption': '(Rightmove) 18.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_06_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_06_0000.jpeg',
#      'caption': '(Rightmove) 14.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_21_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_21_0000.jpeg',
#      'caption': '(Rightmove) 13.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_22_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_22_0000.jpeg',
#      'caption': '(Rightmove) 9.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_11_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_11_0000.jpeg',
#      'caption': '(Rightmove) 28.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_10_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_10_0000.jpeg',
#      'caption': '(Rightmove) 30.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_25_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_25_0000.jpeg',
#      'caption': '(Rightmove) 39.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_26_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_26_0000.jpeg',
#      'caption': '(Rightmove) 37.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_27_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_27_0000.jpeg',
#      'caption': '(Rightmove) 38.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_28_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_28_0000.jpeg',
#      'caption': '(Rightmove) 2.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_29_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_29_0000.jpeg',
#      'caption': '(Rightmove) 31.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_30_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_30_0000.jpeg',
#      'caption': '(Rightmove) 42.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_31_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_31_0000.jpeg',
#      'caption': '(Rightmove) 4.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_32_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_32_0000.jpeg',
#      'caption': '(Rightmove) 8.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_33_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_33_0000.jpeg',
#      'caption': '(Rightmove) 17.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_34_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_34_0000.jpeg',
#      'caption': '(Rightmove) 15.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_35_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_35_0000.jpeg',
#      'caption': '(Rightmove) 24.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_36_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_36_0000.jpeg',
#      'caption': '(Rightmove) 21.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_37_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_37_0000.jpeg',
#      'caption': '(Rightmove) 22.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_38_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_38_0000.jpeg',
#      'caption': '(Rightmove) 26.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_39_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_39_0000.jpeg',
#      'caption': '(Rightmove) 29.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_40_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_40_0000.jpeg',
#      'caption': '(Rightmove) 34.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_41_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_41_0000.jpeg',
#      'caption': '(Rightmove) 33.jpg'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_42_0000_max_476x317.jpeg',
#      'url': '11k/10255/89373922/10255_30433865_IMG_42_0000.jpeg',
#      'caption': '(Rightmove) 3.jpg'}],
#    'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_43_0000_max_476x317.jpeg',
#    'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/11k/10255/89373922/10255_30433865_IMG_43_0000_max_296x197.jpeg'},
#   'displayStatus': '',
#   'formattedBranchName': ' by The Personal Agent, Epsom',
#   'addedOrReduced': 'Added on 26/02/2021',
#   'isRecent': False,
#   'formattedDistance': '',
#   'hasBrandPlus': True,
#   'propertyTypeFullDescription': '4 bedroom detached house for sale',
#   'heading': 'Featured Property',
#   'enhancedListing': False},
#  {'id': 102640925,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'numberOfImages': 9,
#   'numberOfFloorplans': 1,
#   'numberOfVirtualTours': 1,
#   'summary': 'Just 2 x 2 bedroom apartments remaining Situated between Kingston´s historic Market Place and the River Thames, Riverside Place is an extremely desirable development of just 26 one and two bedroom apartments. The apartments are elegantly designed to the very highest specification. The ...',
#   'displayAddress': 'Riverside Place, Thames Street, Kingston upon Thames',
#   'countryCode': 'GB',
#   'location': {'latitude': 51.41023, 'longitude': -0.30805},
#   'propertySubType': 'Apartment',
#   'listingUpdate': {'listingUpdateReason': 'new',
#    'listingUpdateDate': '2021-02-09T17:21:06Z'},
#   'premiumListing': False,
#   'featuredProperty': False,
#   'price': {'amount': 566428,
#    'frequency': 'not specified',
#    'currencyCode': 'GBP',
#    'displayPrices': [{'displayPrice': '£566,428',
#      'displayPriceQualifier': ''}]},
#   'customer': {'branchId': 46386,
#    'brandPlusLogoURI': '/company/clogo_14256_0001.jpg',
#    'contactTelephone': '020 8012 5264',
#    'branchDisplayName': 'Stack & Bonner, Kingston Upon Thames',
#    'branchName': 'Kingston Upon Thames',
#    'brandTradingName': 'Stack & Bonner',
#    'branchLandingPageUrl': '/estate-agents/agent/Stack-and-Bonner/Kingston-Upon-Thames-46386.html',
#    'development': False,
#    'showReducedProperties': True,
#    'commercial': False,
#    'showOnMap': True,
#    'enhancedListing': False,
#    'developmentContent': None,
#    'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/company/clogo_14256_0001_max_100x50.jpg'},
#   'distance': None,
#   'transactionType': 'buy',
#   'productLabel': {'productLabelText': '', 'spotlightLabel': False},
#   'commercial': False,
#   'development': True,
#   'residential': True,
#   'students': False,
#   'auction': False,
#   'feesApply': False,
#   'feesApplyText': None,
#   'displaySize': '752 sq. ft.',
#   'showOnMap': True,
#   'propertyUrl': '/properties/102640925',
#   'contactUrl': '/property-for-sale/contactBranch.html?propertyId=102640925',
#   'staticMapUrl': None,
#   'channel': 'BUY',
#   'firstVisibleDate': '2021-02-09T17:15:54Z',
#   'keywords': [],
#   'keywordMatchType': 'no_keyword',
#   'saved': False,
#   'hidden': False,
#   'onlineViewingsAvailable': False,
#   'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/47k/46386/102640925/46386_100723005041_IMG_09_0000_max_476x317.jpeg',
#      'url': '47k/46386/102640925/46386_100723005041_IMG_09_0000.jpeg',
#      'caption': 'Indicative CGI'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/47k/46386/102640925/46386_100723005041_IMG_01_0000_max_476x317.jpeg',
#      'url': '47k/46386/102640925/46386_100723005041_IMG_01_0000.jpeg',
#      'caption': 'Indicative CGI'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/47k/46386/102640925/46386_100723005041_IMG_02_0000_max_476x317.jpeg',
#      'url': '47k/46386/102640925/46386_100723005041_IMG_02_0000.jpeg',
#      'caption': 'Indicative CGI'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/47k/46386/102640925/46386_100723005041_IMG_03_0000_max_476x317.jpeg',
#      'url': '47k/46386/102640925/46386_100723005041_IMG_03_0000.jpeg',
#      'caption': 'Indicative CGI'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/47k/46386/102640925/46386_100723005041_IMG_04_0000_max_476x317.jpeg',
#      'url': '47k/46386/102640925/46386_100723005041_IMG_04_0000.jpeg',
#      'caption': 'Indicative CGI'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/47k/46386/102640925/46386_100723005041_IMG_05_0000_max_476x317.jpeg',
#      'url': '47k/46386/102640925/46386_100723005041_IMG_05_0000.jpeg',
#      'caption': 'Indicative CGI'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/47k/46386/102640925/46386_100723005041_IMG_06_0000_max_476x317.jpeg',
#      'url': '47k/46386/102640925/46386_100723005041_IMG_06_0000.jpeg',
#      'caption': 'Indicative CGI'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/47k/46386/102640925/46386_100723005041_IMG_07_0000_max_476x317.jpeg',
#      'url': '47k/46386/102640925/46386_100723005041_IMG_07_0000.jpeg',
#      'caption': 'Indicative CGI'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/47k/46386/102640925/46386_100723005041_IMG_08_0000_max_476x317.jpeg',
#      'url': '47k/46386/102640925/46386_100723005041_IMG_08_0000.jpeg',
#      'caption': 'Indicative CGI'}],
#    'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/47k/46386/102640925/46386_100723005041_IMG_09_0000_max_476x317.jpeg',
#    'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/47k/46386/102640925/46386_100723005041_IMG_09_0000_max_296x197.jpeg'},
#   'displayStatus': '',
#   'formattedBranchName': ' by Stack & Bonner, Kingston Upon Thames',
#   'addedOrReduced': 'Added on 09/02/2021',
#   'isRecent': False,
#   'formattedDistance': '',
#   'hasBrandPlus': True,
#   'propertyTypeFullDescription': '2 bedroom apartment for sale',
#   'heading': '',
#   'enhancedListing': False},
#  {'id': 82687970,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'numberOfImages': 16,
#   'numberOfFloorplans': 1,
#   'numberOfVirtualTours': 0,
#   'summary': 'A SPACIOUS 2 BED 2 BATH GROUND FLOOR south-facing apartment set in 5 acres of beautiful, secure and gated landscaped grounds leading down to the River Mole. Situated in the heart of East Molesey and within easy reach of Hampton Court Palace, British Rail, The River Thames and all local amenities.',
#   'displayAddress': 'Molesey Park Road, East Molesey, Surrey, KT8',
#   'countryCode': 'GB',
#   'location': {'latitude': 51.39582, 'longitude': -0.35673},
#   'propertySubType': 'Ground Flat',
#   'listingUpdate': {'listingUpdateReason': 'new',
#    'listingUpdateDate': '2021-02-12T17:48:44Z'},
#   'premiumListing': False,
#   'featuredProperty': False,
#   'price': {'amount': 565000,
#    'frequency': 'not specified',
#    'currencyCode': 'GBP',
#    'displayPrices': [{'displayPrice': '£565,000',
#      'displayPriceQualifier': ''}]},
#   'customer': {'branchId': 149837,
#    'brandPlusLogoURI': '/company/clogo_rmchoice_7277_0003.jpeg',
#    'contactTelephone': '020 8012 6371',
#    'branchDisplayName': 'Dowling Styles, East Molesey',
#    'branchName': 'East Molesey',
#    'brandTradingName': 'Dowling Styles',
#    'branchLandingPageUrl': '/estate-agents/agent/Dowling-Styles/East-Molesey-149837.html',
#    'development': False,
#    'showReducedProperties': True,
#    'commercial': False,
#    'showOnMap': True,
#    'enhancedListing': False,
#    'developmentContent': None,
#    'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/company/clogo_rmchoice_7277_0003_max_100x50.jpeg'},
#   'distance': None,
#   'transactionType': 'buy',
#   'productLabel': {'productLabelText': '', 'spotlightLabel': False},
#   'commercial': False,
#   'development': False,
#   'residential': True,
#   'students': False,
#   'auction': False,
#   'feesApply': False,
#   'feesApplyText': None,
#   'displaySize': '1,057 sq. ft.',
#   'showOnMap': True,
#   'propertyUrl': '/properties/82687970',
#   'contactUrl': '/property-for-sale/contactBranch.html?propertyId=82687970',
#   'staticMapUrl': None,
#   'channel': 'BUY',
#   'firstVisibleDate': '2019-06-19T22:20:36Z',
#   'keywords': [],
#   'keywordMatchType': 'no_keyword',
#   'saved': False,
#   'hidden': False,
#   'onlineViewingsAvailable': False,
#   'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_00_0000_max_476x317.jpg',
#      'url': '150k/149837/82687970/149837_S127_IMG_00_0000.jpg',
#      'caption': 'Front view.'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_17_0000_max_476x317.jpg',
#      'url': '150k/149837/82687970/149837_S127_IMG_17_0000.jpg',
#      'caption': 'Rear view.'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_03_0000_max_476x317.jpg',
#      'url': '150k/149837/82687970/149837_S127_IMG_03_0000.jpg',
#      'caption': 'Front entrance.'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_01_0000_max_476x317.jpg',
#      'url': '150k/149837/82687970/149837_S127_IMG_01_0000.jpg',
#      'caption': 'Entrance hallway.'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_27_0000_max_476x317.jpg',
#      'url': '150k/149837/82687970/149837_S127_IMG_27_0000.jpg',
#      'caption': 'Communal lounge.'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_34_0000_max_476x317.jpeg',
#      'url': '150k/149837/82687970/149837_S127_IMG_34_0000.jpeg',
#      'caption': 'Reception.'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_35_0001_max_476x317.jpeg',
#      'url': '150k/149837/82687970/149837_S127_IMG_35_0001.jpeg',
#      'caption': 'Reception.'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_33_0000_max_476x317.jpeg',
#      'url': '150k/149837/82687970/149837_S127_IMG_33_0000.jpeg',
#      'caption': 'Kitchen.'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_31_0000_max_476x317.jpeg',
#      'url': '150k/149837/82687970/149837_S127_IMG_31_0000.jpeg',
#      'caption': 'Bedroom 1.'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_29_0000_max_476x317.jpeg',
#      'url': '150k/149837/82687970/149837_S127_IMG_29_0000.jpeg',
#      'caption': 'Bed 1 ensuite.'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_32_0000_max_476x317.jpeg',
#      'url': '150k/149837/82687970/149837_S127_IMG_32_0000.jpeg',
#      'caption': 'Bedroom 2.'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_30_0000_max_476x317.jpeg',
#      'url': '150k/149837/82687970/149837_S127_IMG_30_0000.jpeg',
#      'caption': 'Family bathroom.'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_14_0000_max_476x317.jpg',
#      'url': '150k/149837/82687970/149837_S127_IMG_14_0000.jpg',
#      'caption': 'Rear gardens.'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_15_0000_max_476x317.jpg',
#      'url': '150k/149837/82687970/149837_S127_IMG_15_0000.jpg',
#      'caption': 'Bridge over river.'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_13_0000_max_476x317.jpg',
#      'url': '150k/149837/82687970/149837_S127_IMG_13_0000.jpg',
#      'caption': 'Front driveway.'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_28_0000_max_476x317.jpg',
#      'url': '150k/149837/82687970/149837_S127_IMG_28_0000.jpg',
#      'caption': 'Driveway.'}],
#    'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_00_0000_max_476x317.jpg',
#    'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/150k/149837/82687970/149837_S127_IMG_00_0000_max_296x197.jpg'},
#   'displayStatus': '',
#   'formattedBranchName': ' by Dowling Styles, East Molesey',
#   'addedOrReduced': 'Added on 12/02/2021',
#   'isRecent': False,
#   'formattedDistance': '',
#   'hasBrandPlus': True,
#   'propertyTypeFullDescription': '2 bedroom ground floor flat for sale',
#   'heading': '',
#   'enhancedListing': False},
#  {'id': 78090109,
#   'bedrooms': 3,
#   'bathrooms': 2,
#   'numberOfImages': 11,
#   'numberOfFloorplans': 1,
#   'numberOfVirtualTours': 0,
#   'summary': 'A spacious bright three bedroom second floor flat with two reception rooms and well kept communal gardens, set in this stunning Grade II listed period building within a short walk of Epsom Town Centre and Station. The property has been recently upgraded having been finished to a modern contempora...',
#   'displayAddress': 'Epsom',
#   'countryCode': 'GB',
#   'location': {'latitude': 51.33261, 'longitude': -0.259528},
#   'propertySubType': 'Flat',
#   'listingUpdate': {'listingUpdateReason': 'price_reduced',
#    'listingUpdateDate': '2020-09-22T15:49:56Z'},
#   'premiumListing': True,
#   'featuredProperty': False,
#   'price': {'amount': 565000,
#    'frequency': 'not specified',
#    'currencyCode': 'GBP',
#    'displayPrices': [{'displayPrice': '£565,000',
#      'displayPriceQualifier': ''}]},
#   'customer': {'branchId': 2652,
#    'brandPlusLogoURI': '/3k/2652/branch_rmchoice_logo_2652_0000.jpeg',
#    'contactTelephone': '01372 629019',
#    'branchDisplayName': 'Michael Everett & Co, Epsom - Sales & Lettings',
#    'branchName': 'Epsom - Sales & Lettings',
#    'brandTradingName': 'Michael Everett & Co',
#    'branchLandingPageUrl': '/estate-agents/agent/Michael-Everett-and-Co/Epsom---Sales-and-Lettings-2652.html',
#    'development': False,
#    'showReducedProperties': True,
#    'commercial': False,
#    'showOnMap': True,
#    'enhancedListing': False,
#    'developmentContent': None,
#    'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/3k/2652/branch_rmchoice_logo_2652_0000_max_100x50.jpeg'},
#   'distance': None,
#   'transactionType': 'buy',
#   'productLabel': {'productLabelText': 'Premium Listing',
#    'spotlightLabel': False},
#   'commercial': False,
#   'development': False,
#   'residential': True,
#   'students': False,
#   'auction': False,
#   'feesApply': False,
#   'feesApplyText': None,
#   'displaySize': '',
#   'showOnMap': True,
#   'propertyUrl': '/properties/78090109',
#   'contactUrl': '/property-for-sale/contactBranch.html?propertyId=78090109',
#   'staticMapUrl': None,
#   'channel': 'BUY',
#   'firstVisibleDate': '2020-03-10T10:13:55Z',
#   'keywords': [],
#   'keywordMatchType': 'no_keyword',
#   'saved': False,
#   'hidden': False,
#   'onlineViewingsAvailable': False,
#   'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/3k/2652/78090109/2652_10214433_IMG_01_0000_max_476x317.jpg',
#      'url': '3k/2652/78090109/2652_10214433_IMG_01_0000.jpg',
#      'caption': 'Photo 1'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/3k/2652/78090109/2652_10214433_IMG_03_0000_max_476x317.jpg',
#      'url': '3k/2652/78090109/2652_10214433_IMG_03_0000.jpg',
#      'caption': 'Photo 3'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/3k/2652/78090109/2652_10214433_IMG_02_0000_max_476x317.jpg',
#      'url': '3k/2652/78090109/2652_10214433_IMG_02_0000.jpg',
#      'caption': 'Photo 7'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/3k/2652/78090109/2652_10214433_IMG_04_0000_max_476x317.jpg',
#      'url': '3k/2652/78090109/2652_10214433_IMG_04_0000.jpg',
#      'caption': 'Photo 8'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/3k/2652/78090109/2652_10214433_IMG_05_0000_max_476x317.jpg',
#      'url': '3k/2652/78090109/2652_10214433_IMG_05_0000.jpg',
#      'caption': 'Photo 10'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/3k/2652/78090109/2652_10214433_IMG_06_0000_max_476x317.jpg',
#      'url': '3k/2652/78090109/2652_10214433_IMG_06_0000.jpg',
#      'caption': 'Photo 11'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/3k/2652/78090109/2652_10214433_IMG_07_0000_max_476x317.jpg',
#      'url': '3k/2652/78090109/2652_10214433_IMG_07_0000.jpg',
#      'caption': 'Photo 9'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/3k/2652/78090109/2652_10214433_IMG_08_0000_max_476x317.jpg',
#      'url': '3k/2652/78090109/2652_10214433_IMG_08_0000.jpg',
#      'caption': 'Photo 6'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/3k/2652/78090109/2652_10214433_IMG_09_0000_max_476x317.jpg',
#      'url': '3k/2652/78090109/2652_10214433_IMG_09_0000.jpg',
#      'caption': 'Photo 5'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/3k/2652/78090109/2652_10214433_IMG_10_0000_max_476x317.jpg',
#      'url': '3k/2652/78090109/2652_10214433_IMG_10_0000.jpg',
#      'caption': 'Photo 4'},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/3k/2652/78090109/2652_10214433_IMG_11_0000_max_476x317.jpg',
#      'url': '3k/2652/78090109/2652_10214433_IMG_11_0000.jpg',
#      'caption': 'Photo 2'}],
#    'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/3k/2652/78090109/2652_10214433_IMG_01_0000_max_476x317.jpg',
#    'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/3k/2652/78090109/2652_10214433_IMG_01_0000_max_296x197.jpg'},
#   'displayStatus': '',
#   'formattedBranchName': ' by Michael Everett & Co, Epsom - Sales & Lettings',
#   'addedOrReduced': 'Reduced on 22/09/2020',
#   'isRecent': False,
#   'formattedDistance': '',
#   'hasBrandPlus': True,
#   'propertyTypeFullDescription': '3 bedroom flat for sale',
#   'heading': '',
#   'enhancedListing': False},
#  {'id': 92571371,
#   'bedrooms': 2,
#   'bathrooms': None,
#   'numberOfImages': 10,
#   'numberOfFloorplans': 1,
#   'numberOfVirtualTours': 0,
#   'summary': 'Located just a few hundred yards from the shops and restaurants of Queens Road and within a mile of Weybridge mainline station, this lift served, first floor, two bedroom, two bathroom apartment is offered for sale in immaculate condition throughout and has been exceptionally well cared for by our c',
#   'displayAddress': 'Queens Road, Weybridge, Surrey, KT13',
#   'countryCode': 'GB',
#   'location': {'latitude': 51.3652, 'longitude': -0.43885},
#   'propertySubType': 'Apartment',
#   'listingUpdate': {'listingUpdateReason': 'price_reduced',
#    'listingUpdateDate': '2020-07-28T12:07:54Z'},
#   'premiumListing': False,
#   'featuredProperty': False,
#   'price': {'amount': 565000,
#    'frequency': 'not specified',
#    'currencyCode': 'GBP',
#    'displayPrices': [{'displayPrice': '£565,000',
#      'displayPriceQualifier': ''}]},
#   'customer': {'branchId': 12260,
#    'brandPlusLogoURI': '/company/clogo_rmchoice_4370_0000.jpeg',
#    'contactTelephone': '01932 485041',
#    'branchDisplayName': 'Martin Flashman & Co., Weybridge',
#    'branchName': 'Weybridge',
#    'brandTradingName': 'Martin Flashman & Co.',
#    'branchLandingPageUrl': '/estate-agents/agent/Martin-Flashman-and-Co/Weybridge-12260.html',
#    'development': False,
#    'showReducedProperties': True,
#    'commercial': False,
#    'showOnMap': True,
#    'enhancedListing': False,
#    'developmentContent': None,
#    'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/company/clogo_rmchoice_4370_0000_max_100x50.jpeg'},
#   'distance': None,
#   'transactionType': 'buy',
#   'productLabel': {'productLabelText': '', 'spotlightLabel': False},
#   'commercial': False,
#   'development': False,
#   'residential': True,
#   'students': False,
#   'auction': False,
#   'feesApply': False,
#   'feesApplyText': None,
#   'displaySize': '',
#   'showOnMap': True,
#   'propertyUrl': '/properties/92571371',
#   'contactUrl': '/property-for-sale/contactBranch.html?propertyId=92571371',
#   'staticMapUrl': None,
#   'channel': 'BUY',
#   'firstVisibleDate': '2020-05-22T14:30:24Z',
#   'keywords': [],
#   'keywordMatchType': 'no_keyword',
#   'saved': False,
#   'hidden': False,
#   'onlineViewingsAvailable': False,
#   'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12260/92571371/12260_220520_IMG_07_0000_max_476x317.jpg',
#      'url': '13k/12260/92571371/12260_220520_IMG_07_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12260/92571371/12260_220520_IMG_08_0000_max_476x317.jpg',
#      'url': '13k/12260/92571371/12260_220520_IMG_08_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12260/92571371/12260_220520_IMG_03_0000_max_476x317.jpg',
#      'url': '13k/12260/92571371/12260_220520_IMG_03_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12260/92571371/12260_220520_IMG_09_0000_max_476x317.jpg',
#      'url': '13k/12260/92571371/12260_220520_IMG_09_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12260/92571371/12260_220520_IMG_01_0000_max_476x317.jpg',
#      'url': '13k/12260/92571371/12260_220520_IMG_01_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12260/92571371/12260_220520_IMG_02_0000_max_476x317.jpg',
#      'url': '13k/12260/92571371/12260_220520_IMG_02_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12260/92571371/12260_220520_IMG_00_0000_max_476x317.jpg',
#      'url': '13k/12260/92571371/12260_220520_IMG_00_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12260/92571371/12260_220520_IMG_04_0000_max_476x317.jpg',
#      'url': '13k/12260/92571371/12260_220520_IMG_04_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12260/92571371/12260_220520_IMG_06_0000_max_476x317.jpg',
#      'url': '13k/12260/92571371/12260_220520_IMG_06_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12260/92571371/12260_220520_IMG_05_0000_max_476x317.jpg',
#      'url': '13k/12260/92571371/12260_220520_IMG_05_0000.jpg',
#      'caption': None}],
#    'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12260/92571371/12260_220520_IMG_07_0000_max_476x317.jpg',
#    'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12260/92571371/12260_220520_IMG_07_0000_max_296x197.jpg'},
#   'displayStatus': '',
#   'formattedBranchName': ' by Martin Flashman & Co., Weybridge',
#   'addedOrReduced': 'Reduced on 28/07/2020',
#   'isRecent': False,
#   'formattedDistance': '',
#   'hasBrandPlus': True,
#   'propertyTypeFullDescription': '2 bedroom apartment for sale',
#   'heading': '',
#   'enhancedListing': False},
#  {'id': 101727014,
#   'bedrooms': 3,
#   'bathrooms': None,
#   'numberOfImages': 11,
#   'numberOfFloorplans': 3,
#   'numberOfVirtualTours': 1,
#   'summary': 'HOME OF THE MONTH. Available with ?1,000 towards Legal Fees* and Flooring. An impressive family home, boasting a PRIVATE DRIVEWAY, 2 EN SUITE BEDROOMS, open plan sitting room and dining room with access to the TURFED GARDEN. Find out more...',
#   'displayAddress': 'Stonehill Road, \r\nChertsey, \r\nSurrey, \r\nKT16 0AG',
#   'countryCode': 'GB',
#   'location': {'latitude': 51.37776, 'longitude': -0.52708},
#   'propertySubType': 'Semi-Detached',
#   'listingUpdate': {'listingUpdateReason': 'price_reduced',
#    'listingUpdateDate': '2021-01-26T01:45:01Z'},
#   'premiumListing': False,
#   'featuredProperty': False,
#   'price': {'amount': 565000,
#    'frequency': 'not specified',
#    'currencyCode': 'GBP',
#    'displayPrices': [{'displayPrice': '£565,000',
#      'displayPriceQualifier': 'From'}]},
#   'customer': {'branchId': 223916,
#    'brandPlusLogoURI': '/company/clogo_2929_0003.jpeg',
#    'contactTelephone': '01932 485017',
#    'branchDisplayName': 'CALA Homes',
#    'branchName': 'St Peters Quarter',
#    'brandTradingName': 'CALA Homes',
#    'branchLandingPageUrl': '/developer/branch/CALA-Homes/St-Peters-Quarter-223916.html',
#    'development': True,
#    'showReducedProperties': True,
#    'commercial': False,
#    'showOnMap': True,
#    'enhancedListing': True,
#    'developmentContent': {'headline': 'ST PETER\x92S QUARTER, CHERTSEY \x96 EXCITING NEW COLLECTION OF 3 & 4 BEDROOM, HIGH SPECIFICATION FAMILY HOMES',
#     'features': ['3 & 4 bedroom family homes',
#      'Set amongst green open spaces',
#      'Fantastic schools nearby',
#      'Great amenities & commuter links']},
#    'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/company/clogo_2929_0003_max_100x50.jpeg'},
#   'distance': None,
#   'transactionType': 'buy',
#   'productLabel': {'productLabelText': 'Part Exchange',
#    'spotlightLabel': True},
#   'commercial': False,
#   'development': True,
#   'residential': True,
#   'students': False,
#   'auction': False,
#   'feesApply': False,
#   'feesApplyText': None,
#   'displaySize': '',
#   'showOnMap': True,
#   'propertyUrl': '/properties/101727014',
#   'contactUrl': '/property-for-sale/contactBranch.html?propertyId=101727014',
#   'staticMapUrl': 'https://media.rightmove.co.uk:443/map/_generate?width=231&height=96&zoomLevel=11&latitude=51.37776&longitude=-0.52708&signature=SJqjtP_OD2nLyZM5_xk8rI74_Ek=',
#   'channel': 'BUY',
#   'firstVisibleDate': '2021-01-06T09:37:38Z',
#   'keywords': [],
#   'keywordMatchType': 'no_keyword',
#   'saved': False,
#   'hidden': False,
#   'onlineViewingsAvailable': False,
#   'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/224k/223916/101727014/223916_28600_3_37_100774_IMG_01_0000_max_476x317.jpg',
#      'url': '224k/223916/101727014/223916_28600_3_37_100774_IMG_01_0000.jpg',
#      'caption': "st peter's quarter, chertsey"},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/224k/223916/101727014/223916_28600_3_37_100774_IMG_02_0000_max_476x317.jpg',
#      'url': '224k/223916/101727014/223916_28600_3_37_100774_IMG_02_0000.jpg',
#      'caption': "st peter's quarter, chertsey"},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/224k/223916/101727014/223916_28600_3_37_100774_IMG_03_0000_max_476x317.jpg',
#      'url': '224k/223916/101727014/223916_28600_3_37_100774_IMG_03_0000.jpg',
#      'caption': "st peter's quarter, chertsey"},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/224k/223916/101727014/223916_28600_3_37_100774_IMG_04_0000_max_476x317.jpg',
#      'url': '224k/223916/101727014/223916_28600_3_37_100774_IMG_04_0000.jpg',
#      'caption': "st peter's quarter, chertsey"},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/224k/223916/101727014/223916_28600_3_37_100774_IMG_06_0000_max_476x317.jpg',
#      'url': '224k/223916/101727014/223916_28600_3_37_100774_IMG_06_0000.jpg',
#      'caption': "st peter's quarter, chertsey"},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/224k/223916/101727014/223916_28600_3_37_100774_IMG_07_0000_max_476x317.jpg',
#      'url': '224k/223916/101727014/223916_28600_3_37_100774_IMG_07_0000.jpg',
#      'caption': "st peter's quarter, chertsey"},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/224k/223916/101727014/223916_28600_3_37_100774_IMG_08_0000_max_476x317.jpg',
#      'url': '224k/223916/101727014/223916_28600_3_37_100774_IMG_08_0000.jpg',
#      'caption': "st peter's quarter, chertsey"},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/224k/223916/101727014/223916_28600_3_37_100774_IMG_09_0000_max_476x317.jpg',
#      'url': '224k/223916/101727014/223916_28600_3_37_100774_IMG_09_0000.jpg',
#      'caption': "st peter's quarter, chertsey"},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/224k/223916/101727014/223916_28600_3_37_100774_IMG_10_0000_max_476x317.jpg',
#      'url': '224k/223916/101727014/223916_28600_3_37_100774_IMG_10_0000.jpg',
#      'caption': "st peter's quarter, chertsey"},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/224k/223916/101727014/223916_28600_3_37_100774_IMG_11_0000_max_476x317.jpg',
#      'url': '224k/223916/101727014/223916_28600_3_37_100774_IMG_11_0000.jpg',
#      'caption': "st peter's quarter, chertsey"},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/224k/223916/101727014/223916_28600_3_37_100774_IMG_12_0000_max_476x317.jpg',
#      'url': '224k/223916/101727014/223916_28600_3_37_100774_IMG_12_0000.jpg',
#      'caption': "st peter's quarter, chertsey"}],
#    'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/224k/223916/101727014/223916_28600_3_37_100774_IMG_01_0000_max_476x317.jpg',
#    'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/224k/223916/101727014/223916_28600_3_37_100774_IMG_01_0000_max_296x197.jpg'},
#   'displayStatus': '',
#   'formattedBranchName': ' by CALA Homes',
#   'addedOrReduced': 'Reduced on 26/01/2021',
#   'isRecent': False,
#   'formattedDistance': '',
#   'hasBrandPlus': True,
#   'propertyTypeFullDescription': '3 bedroom semi-detached house for sale',
#   'heading': '',
#   'enhancedListing': True},
#  {'id': 100446782,
#   'bedrooms': 3,
#   'bathrooms': None,
#   'numberOfImages': 15,
#   'numberOfFloorplans': 1,
#   'numberOfVirtualTours': 0,
#   'summary': 'Highly desirable three bedroom home positioned in the Church Green development located in the heart of Hersham Village and set adjacent to the picturesque Back Green. ',
#   'displayAddress': 'Church Green, Hersham Village, Surrey, KT12',
#   'countryCode': 'GB',
#   'location': {'latitude': 51.3637, 'longitude': -0.40098},
#   'propertySubType': 'Terraced',
#   'listingUpdate': {'listingUpdateReason': 'new',
#    'listingUpdateDate': '2021-01-19T09:23:38Z'},
#   'premiumListing': False,
#   'featuredProperty': False,
#   'price': {'amount': 565000,
#    'frequency': 'not specified',
#    'currencyCode': 'GBP',
#    'displayPrices': [{'displayPrice': '£565,000',
#      'displayPriceQualifier': ''}]},
#   'customer': {'branchId': 12261,
#    'brandPlusLogoURI': '/company/clogo_rmchoice_4370_0000.jpeg',
#    'contactTelephone': '01932 485042',
#    'branchDisplayName': 'Martin Flashman & Co., Walton-on-Thames',
#    'branchName': 'Walton-on-Thames',
#    'brandTradingName': 'Martin Flashman & Co.',
#    'branchLandingPageUrl': '/estate-agents/agent/Martin-Flashman-and-Co/Walton-on-Thames-12261.html',
#    'development': False,
#    'showReducedProperties': True,
#    'commercial': False,
#    'showOnMap': True,
#    'enhancedListing': False,
#    'developmentContent': None,
#    'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/company/clogo_rmchoice_4370_0000_max_100x50.jpeg'},
#   'distance': None,
#   'transactionType': 'buy',
#   'productLabel': {'productLabelText': '', 'spotlightLabel': False},
#   'commercial': False,
#   'development': False,
#   'residential': True,
#   'students': False,
#   'auction': False,
#   'feesApply': False,
#   'feesApplyText': None,
#   'displaySize': '',
#   'showOnMap': True,
#   'propertyUrl': '/properties/100446782',
#   'contactUrl': '/property-for-sale/contactBranch.html?propertyId=100446782',
#   'staticMapUrl': None,
#   'channel': 'BUY',
#   'firstVisibleDate': '2020-11-26T11:27:10Z',
#   'keywords': [],
#   'keywordMatchType': 'no_keyword',
#   'saved': False,
#   'hidden': False,
#   'onlineViewingsAvailable': False,
#   'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_07_0000_max_476x317.jpeg',
#      'url': '13k/12261/100446782/12261_261120202_IMG_07_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_10_0000_max_476x317.jpeg',
#      'url': '13k/12261/100446782/12261_261120202_IMG_10_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_08_0000_max_476x317.jpeg',
#      'url': '13k/12261/100446782/12261_261120202_IMG_08_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_09_0000_max_476x317.jpeg',
#      'url': '13k/12261/100446782/12261_261120202_IMG_09_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_06_0000_max_476x317.jpeg',
#      'url': '13k/12261/100446782/12261_261120202_IMG_06_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_13_0000_max_476x317.jpeg',
#      'url': '13k/12261/100446782/12261_261120202_IMG_13_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_12_0000_max_476x317.jpeg',
#      'url': '13k/12261/100446782/12261_261120202_IMG_12_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_11_0000_max_476x317.jpeg',
#      'url': '13k/12261/100446782/12261_261120202_IMG_11_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_14_0000_max_476x317.jpeg',
#      'url': '13k/12261/100446782/12261_261120202_IMG_14_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_03_0000_max_476x317.jpeg',
#      'url': '13k/12261/100446782/12261_261120202_IMG_03_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_04_0000_max_476x317.jpeg',
#      'url': '13k/12261/100446782/12261_261120202_IMG_04_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_00_0000_max_476x317.jpeg',
#      'url': '13k/12261/100446782/12261_261120202_IMG_00_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_02_0000_max_476x317.jpeg',
#      'url': '13k/12261/100446782/12261_261120202_IMG_02_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_01_0000_max_476x317.jpeg',
#      'url': '13k/12261/100446782/12261_261120202_IMG_01_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_05_0000_max_476x317.jpeg',
#      'url': '13k/12261/100446782/12261_261120202_IMG_05_0000.jpeg',
#      'caption': None}],
#    'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_07_0000_max_476x317.jpeg',
#    'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/13k/12261/100446782/12261_261120202_IMG_07_0000_max_296x197.jpeg'},
#   'displayStatus': '',
#   'formattedBranchName': ' by Martin Flashman & Co., Walton-on-Thames',
#   'addedOrReduced': 'Added on 19/01/2021',
#   'isRecent': False,
#   'formattedDistance': '',
#   'hasBrandPlus': True,
#   'propertyTypeFullDescription': '3 bedroom terraced house for sale',
#   'heading': '',
#   'enhancedListing': False},
#  {'id': 100731035,
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'numberOfImages': 9,
#   'numberOfFloorplans': 1,
#   'numberOfVirtualTours': 0,
# ...
#    'commercial': False,
#    'showOnMap': True,
#    'enhancedListing': False,
#    'developmentContent': None,
#    'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/brand/brand_rmchoice_logo_282_0004_max_100x50.jpeg'},
#   'distance': None,
#   'transactionType': 'buy',
#   'productLabel': {'productLabelText': 'Virtual Tour',
#    'spotlightLabel': False},
#   'commercial': False,
#   'development': False,
#   'residential': True,
#   'students': False,
#   'auction': False,
#   'feesApply': False,
#   'feesApplyText': None,
#   'displaySize': '',
#   'showOnMap': True,
#   'propertyUrl': '/properties/99042143',
#   'contactUrl': '/property-for-sale/contactBranch.html?propertyId=99042143',
#   'staticMapUrl': None,
#   'channel': 'BUY',
#   'firstVisibleDate': '2020-10-27T15:52:29Z',
#   'keywords': [],
#   'keywordMatchType': 'no_keyword',
#   'saved': False,
#   'hidden': False,
#   'onlineViewingsAvailable': True,
#   'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/2k/1902/99042143/1902_EWE103975_IMG_09_0000_max_476x317.JPG',
#      'url': '2k/1902/99042143/1902_EWE103975_IMG_09_0000.JPG',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/2k/1902/99042143/1902_EWE103975_IMG_01_0000_max_476x317.JPG',
#      'url': '2k/1902/99042143/1902_EWE103975_IMG_01_0000.JPG',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/2k/1902/99042143/1902_EWE103975_IMG_02_0000_max_476x317.JPG',
#      'url': '2k/1902/99042143/1902_EWE103975_IMG_02_0000.JPG',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/2k/1902/99042143/1902_EWE103975_IMG_03_0000_max_476x317.JPG',
#      'url': '2k/1902/99042143/1902_EWE103975_IMG_03_0000.JPG',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/2k/1902/99042143/1902_EWE103975_IMG_04_0000_max_476x317.JPG',
#      'url': '2k/1902/99042143/1902_EWE103975_IMG_04_0000.JPG',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/2k/1902/99042143/1902_EWE103975_IMG_05_0000_max_476x317.JPG',
#      'url': '2k/1902/99042143/1902_EWE103975_IMG_05_0000.JPG',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/2k/1902/99042143/1902_EWE103975_IMG_06_0000_max_476x317.JPG',
#      'url': '2k/1902/99042143/1902_EWE103975_IMG_06_0000.JPG',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/2k/1902/99042143/1902_EWE103975_IMG_07_0000_max_476x317.JPG',
#      'url': '2k/1902/99042143/1902_EWE103975_IMG_07_0000.JPG',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/2k/1902/99042143/1902_EWE103975_IMG_08_0000_max_476x317.JPG',
#      'url': '2k/1902/99042143/1902_EWE103975_IMG_08_0000.JPG',
#      'caption': None}],
#    'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/2k/1902/99042143/1902_EWE103975_IMG_09_0000_max_476x317.JPG',
#    'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/2k/1902/99042143/1902_EWE103975_IMG_09_0000_max_296x197.JPG'},
#   'displayStatus': '',
#   'formattedBranchName': ' by Barnard Marcus, Ewell',
#   'addedOrReduced': 'Reduced on 29/12/2020',
#   'isRecent': False,
#   'formattedDistance': '',
#   'hasBrandPlus': True,
#   'propertyTypeFullDescription': '3 bedroom semi-detached house for sale',
#   'heading': '',
#   'enhancedListing': False},
#  {'id': 87124249,
#   'bedrooms': 3,
#   'bathrooms': 1,
#   'numberOfImages': 17,
#   'numberOfFloorplans': 1,
#   'numberOfVirtualTours': 0,
#   'summary': 'A well presented three bedroom family home situated in New Malden close to local amenities and excellent transport links. The property comprises of a large open plan living area combining the reception room with kitchen and dining area. The property also benefits from a private rear garden most...',
#   'displayAddress': 'Byron Ave, New Malden',
#   'countryCode': 'GB',
#   'location': {'latitude': 51.39715, 'longitude': -0.24427},
#   'propertySubType': 'End of Terrace',
#   'listingUpdate': {'listingUpdateReason': 'new',
#    'listingUpdateDate': '2020-11-26T06:04:01Z'},
#   'premiumListing': True,
#   'featuredProperty': False,
#   'price': {'amount': 550000,
#    'frequency': 'not specified',
#    'currencyCode': 'GBP',
#    'displayPrices': [{'displayPrice': '£550,000',
#      'displayPriceQualifier': 'Guide Price'}]},
#   'customer': {'branchId': 142988,
#    'brandPlusLogoURI': '/brand/brand_rmchoice_logo_5736_0001.jpeg',
#    'contactTelephone': '020 8012 5820',
#    'branchDisplayName': 'Hunters, Worcester Park',
#    'branchName': 'Worcester Park',
#    'brandTradingName': 'Hunters',
#    'branchLandingPageUrl': '/estate-agents/agent/Hunters/Worcester-Park-142988.html',
#    'development': False,
#    'showReducedProperties': True,
#    'commercial': False,
#    'showOnMap': True,
#    'enhancedListing': False,
#    'developmentContent': None,
#    'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/brand/brand_rmchoice_logo_5736_0001_max_100x50.jpeg'},
#   'distance': None,
#   'transactionType': 'buy',
#   'productLabel': {'productLabelText': 'No Chain', 'spotlightLabel': False},
#   'commercial': False,
#   'development': False,
#   'residential': True,
#   'students': False,
#   'auction': False,
#   'feesApply': False,
#   'feesApplyText': None,
#   'displaySize': '',
#   'showOnMap': True,
#   'propertyUrl': '/properties/87124249',
#   'contactUrl': '/property-for-sale/contactBranch.html?propertyId=87124249',
#   'staticMapUrl': None,
#   'channel': 'BUY',
#   'firstVisibleDate': '2020-11-26T05:58:59Z',
#   'keywords': [],
#   'keywordMatchType': 'no_keyword',
#   'saved': False,
#   'hidden': False,
#   'onlineViewingsAvailable': False,
#   'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_17_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_17_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_07_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_07_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_05_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_05_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_14_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_14_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_02_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_02_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_03_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_03_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_12_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_12_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_08_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_08_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_04_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_04_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_06_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_06_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_01_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_01_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_09_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_09_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_11_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_11_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_10_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_10_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_13_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_13_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_15_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_15_0000.jpg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_16_0000_max_476x317.jpg',
#      'url': '143k/142988/87124249/142988_SAL204596_IMG_16_0000.jpg',
#      'caption': None}],
#    'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_17_0000_max_476x317.jpg',
#    'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/143k/142988/87124249/142988_SAL204596_IMG_17_0000_max_296x197.jpg'},
#   'displayStatus': '',
#   'formattedBranchName': ' by Hunters, Worcester Park',
#   'addedOrReduced': 'Added on 26/11/2020',
#   'isRecent': False,
#   'formattedDistance': '',
#   'hasBrandPlus': True,
#   'propertyTypeFullDescription': '3 bedroom end of terrace house for sale',
#   'heading': '',
#   'enhancedListing': False},
#  {'id': 101617700,
#   'bedrooms': 3,
#   'bathrooms': None,
#   'numberOfImages': 14,
#   'numberOfFloorplans': 1,
#   'numberOfVirtualTours': 0,
#   'summary': 'BEAT THE STAMP DUTY HOLIDAY ENDING ON THE 31ST MARCH. A three bedroom extended detached house in one of the most sought after roads in Chessington with no forward chain. Viewings highly recommended.',
#   'displayAddress': 'Sherborne Road, Chessington, Surrey, KT9',
#   'countryCode': 'GB',
#   'location': {'latitude': 51.36657, 'longitude': -0.30434},
#   'propertySubType': 'Detached',
#   'listingUpdate': {'listingUpdateReason': 'price_reduced',
#    'listingUpdateDate': '2021-01-30T09:46:50Z'},
#   'premiumListing': False,
#   'featuredProperty': False,
#   'price': {'amount': 550000,
#    'frequency': 'not specified',
#    'currencyCode': 'GBP',
#    'displayPrices': [{'displayPrice': '£550,000',
#      'displayPriceQualifier': 'Offers in Excess of'}]},
#   'customer': {'branchId': 5909,
#    'brandPlusLogoURI': '/company/clogo_1805_0000.jpg',
#    'contactTelephone': '020 8012 2271',
#    'branchDisplayName': 'Compass Property Ltd, Chessington',
#    'branchName': 'Chessington',
#    'brandTradingName': 'Compass Property Ltd',
#    'branchLandingPageUrl': '/estate-agents/agent/Compass-Property-Ltd/Chessington-5909.html',
#    'development': False,
#    'showReducedProperties': True,
#    'commercial': False,
#    'showOnMap': True,
#    'enhancedListing': False,
#    'developmentContent': None,
#    'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/company/clogo_1805_0000_max_100x50.jpg'},
#   'distance': None,
#   'transactionType': 'buy',
#   'productLabel': {'productLabelText': '', 'spotlightLabel': False},
#   'commercial': False,
#   'development': False,
#   'residential': True,
#   'students': False,
#   'auction': False,
#   'feesApply': False,
#   'feesApplyText': None,
#   'displaySize': '',
#   'showOnMap': True,
#   'propertyUrl': '/properties/101617700',
#   'contactUrl': '/property-for-sale/contactBranch.html?propertyId=101617700',
#   'staticMapUrl': None,
#   'channel': 'BUY',
#   'firstVisibleDate': '2021-01-02T11:31:50Z',
#   'keywords': [],
#   'keywordMatchType': 'no_keyword',
#   'saved': False,
#   'hidden': False,
#   'onlineViewingsAvailable': False,
#   'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_00_0000_max_476x317.jpeg',
#      'url': '6k/5909/101617700/5909_2she_IMG_00_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_06_0000_max_476x317.jpeg',
#      'url': '6k/5909/101617700/5909_2she_IMG_06_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_01_0000_max_476x317.jpeg',
#      'url': '6k/5909/101617700/5909_2she_IMG_01_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_02_0000_max_476x317.jpeg',
#      'url': '6k/5909/101617700/5909_2she_IMG_02_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_03_0000_max_476x317.jpeg',
#      'url': '6k/5909/101617700/5909_2she_IMG_03_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_04_0000_max_476x317.jpeg',
#      'url': '6k/5909/101617700/5909_2she_IMG_04_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_05_0000_max_476x317.jpeg',
#      'url': '6k/5909/101617700/5909_2she_IMG_05_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_07_0000_max_476x317.jpeg',
#      'url': '6k/5909/101617700/5909_2she_IMG_07_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_08_0000_max_476x317.jpeg',
#      'url': '6k/5909/101617700/5909_2she_IMG_08_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_09_0000_max_476x317.jpeg',
#      'url': '6k/5909/101617700/5909_2she_IMG_09_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_10_0000_max_476x317.jpeg',
#      'url': '6k/5909/101617700/5909_2she_IMG_10_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_11_0000_max_476x317.jpeg',
#      'url': '6k/5909/101617700/5909_2she_IMG_11_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_12_0000_max_476x317.jpeg',
#      'url': '6k/5909/101617700/5909_2she_IMG_12_0000.jpeg',
#      'caption': None},
#     {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_13_0000_max_476x317.jpeg',
#      'url': '6k/5909/101617700/5909_2she_IMG_13_0000.jpeg',
#      'caption': None}],
#    'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_00_0000_max_476x317.jpeg',
#    'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/6k/5909/101617700/5909_2she_IMG_00_0000_max_296x197.jpeg'},
#   'displayStatus': '',
#   'formattedBranchName': ' by Compass Property Ltd, Chessington',
#   'addedOrReduced': 'Reduced on 30/01/2021',
#   'isRecent': False,
#   'formattedDistance': '',
#   'hasBrandPlus': True,
#   'propertyTypeFullDescription': '3 bedroom detached house for sale',
#   'heading': '',
#   'enhancedListing': False}]

# %%
all_data
# Out:
#              id  bedrooms  bathrooms  numberOfImages  numberOfFloorplans  \
# 0      89386117         4        3.0              19                   1
# 1      76636641         6        0.0              26                   1
# 2      86007409         4        2.0              12                   1
# 3      73255458         2        2.0              11                   1
# 4      88981993         4        2.0              14                   1
# ...         ...       ...        ...             ...                 ...
# 1045   96145934         3        1.0               9                   1
# 1046  102112697         3        NaN              14                   2
# 1047   99042143         3        2.0               9                   1
# 1048   87124249         3        1.0              17                   1
# 1049  101617700         3        NaN              14                   1
#
#       numberOfVirtualTours  \
# 0                        1
# 1                        1
# 2                        0
# 3                        1
# 4                        1
# ...                    ...
# 1045                     0
# 1046                     0
# 1047                     0
# 1048                     0
# 1049                     0
#
#                                                                                                                                                                                                                                                                                                          summary  \
# 0             Tucked away in an enclave of this peaceful residential cul-de-sac, this attractive and spacious terraced property is offered to the market in good condition and benefits from four/five bedrooms with flexible and well appointed accommodation. Built by an award winning developer and benef...
# 1            RARELY AVAILABLE DETACHED FAMILY HOME IN CUL-DE-SAC LOCATION CLOSE TO SCHOOLS AND STATION!!! Cairds are proud to bring to market for only the second time since new, this wonderful detached family home. Well loved and looked after for over 30 years, this substantial detached house is loca...
# 2                                                                                                                                                            Situated in a secluded position within close proximity of Hinchley Wood School and train station is this deceptively spacious detached family home!
# 3               A spectacular air conditioned two bedroom apartment located within an exclusive gated development in Esher with onsite concierge. Located on the second floor, the property briefly comprises a large hallway and open plan living/dining room, separate fitted kitchen, a principal suite co...
# 4         A newly constructed 4 bedroom detached house offering a delightful rear garden, excellent specification and situated in a popular semi rural location. Originally constructed in 2020 this beautifully presented home offers extremely light, bright and contemporary accommodation.  Currently thi...
# ...                                                                                                                                                                                                                                                                                                          ...
# 1045                                                                                                                                               This beautifully presented, three bedroom terrace family home benefits from an open plan kitchen diner leading, to a west facing, decked private rear garden.
# 1046                   The Thespian is a 3-bedroom home that features an open-plan kitchen and dining area, a separate living room, an en suite to bedroom 1 and a stylish family bathroom. *EXPRESS MOVER AVAILABLE - WE WILL HELP SELL YOUR HOME IN AS LITTLE AS 30 DAYS* *NO UPPER CHAIN* *MODERN THROUGHOUT*
# 1047                     ** WE ARE STILL OPEN PLEASE CALL FOR VIEWINGS AND VALUATIONS ** Barnard Marcus are pleased to welcome to the market this spacious three bedroom semi-detached family home. The property is situated within close proximity to Ewell Village and has fantastic potential to extend STPP.
# 1048  A well presented three bedroom family home situated in New Malden close to local amenities and excellent transport links. The property comprises of a large open plan living area combining the reception room with kitchen and dining area. The property also benefits from a private rear garden most...
# 1049                                                                                                      BEAT THE STAMP DUTY HOLIDAY ENDING ON THE 31ST MARCH. A three bedroom extended detached house in one of the most sought after roads in Chessington with no forward chain. Viewings highly recommended.
#
#                                    displayAddress countryCode  \
# 0                             Winter Close, Epsom          GB
# 1                            Boleyn Avenue, Epsom          GB
# 2                         Couchmore Avenue, Esher          GB
# 3       Broomhill Court, Esher Close, Esher, KT10          GB
# 4                                     Chessington          GB
# ...                                           ...         ...
# 1045                   Phyllis Avenue, New Malden          GB
# 1046  West Ewell,\r\nEwell,\r\nEpsom,\r\nKT19 9LN          GB
# 1047                           Ruxley Lane, Epsom          GB
# 1048                        Byron Ave, New Malden          GB
# 1049     Sherborne Road, Chessington, Surrey, KT9          GB
#
#                                              location  ...  \
# 0     {'latitude': 51.338951, 'longitude': -0.262866}  ...
# 1      {'latitude': 51.34777, 'longitude': -0.242032}  ...
# 2       {'latitude': 51.3791, 'longitude': -0.342057}  ...
# 3     {'latitude': 51.365766, 'longitude': -0.367829}  ...
# 4     {'latitude': 51.355801, 'longitude': -0.300656}  ...
# ...                                               ...  ...
# 1045  {'latitude': 51.398266, 'longitude': -0.234223}  ...
# 1046    {'latitude': 51.36223, 'longitude': -0.27247}  ...
# 1047  {'latitude': 51.364906, 'longitude': -0.268977}  ...
# 1048    {'latitude': 51.39715, 'longitude': -0.24427}  ...
# 1049    {'latitude': 51.36657, 'longitude': -0.30434}  ...
#
#      onlineViewingsAvailable displayStatus  \
# 0                      False
# 1                       True
# 2                       True
# 3                      False
# 4                      False
# ...                      ...           ...
# 1045                   False
# 1046                   False
# 1047                    True
# 1048                   False
# 1049                   False
#
#                               formattedBranchName         addedOrReduced  \
# 0                    by The Personal Agent, Epsom    Added on 26/02/2021
# 1      by Cairds The Estate Agents, Epsom - SALES  Reduced on 01/03/2021
# 2                     by Barnard Marcus, Surbiton    Added on 22/10/2020
# 3                     by Fine & Country, Richmond    Added on 15/09/2020
# 4        by Henshaws Estate Agents, Great Bookham    Added on 10/02/2021
# ...                                           ...                    ...
# 1045                by Barnard Marcus, New Malden  Reduced on 30/09/2020
# 1046              by Bellway Homes (South London)    Added on 19/01/2021
# 1047                     by Barnard Marcus, Ewell  Reduced on 29/12/2020
# 1048                   by Hunters, Worcester Park    Added on 26/11/2020
# 1049         by Compass Property Ltd, Chessington  Reduced on 30/01/2021
#
#      isRecent formattedDistance hasBrandPlus            heading  \
# 0       False                           True  Featured Property
# 1       False                           True
# 2       False                           True
# 3       False                           True
# 4       False                           True
# ...       ...               ...          ...                ...
# 1045    False                           True
# 1046    False                           True
# 1047    False                           True
# 1048    False                           True
# 1049    False                           True
#
#      enhancedListing              propertyTypeFullDescription
# 0              False        4 bedroom terraced house for sale
# 1              False        6 bedroom detached house for sale
# 2              False        4 bedroom detached house for sale
# 3              False             2 bedroom apartment for sale
# 4              False        4 bedroom detached house for sale
# ...              ...                                      ...
# 1045           False        3 bedroom terraced house for sale
# 1046           False        3 bedroom detached house for sale
# 1047           False   3 bedroom semi-detached house for sale
# 1048           False  3 bedroom end of terrace house for sale
# 1049           False        3 bedroom detached house for sale
#
# [1050 rows x 47 columns]

# %% [markdown]
# ___

# %% [markdown]
# ### 2. Pre-process Data

# %%
raw_data = all_data
raw_data.columns.tolist()
# Out:
# ['id',
#  'bedrooms',
#  'bathrooms',
#  'numberOfImages',
#  'numberOfFloorplans',
#  'numberOfVirtualTours',
#  'summary',
#  'displayAddress',
#  'countryCode',
#  'location',
#  'propertySubType',
#  'listingUpdate',
#  'premiumListing',
#  'featuredProperty',
#  'price',
#  'customer',
#  'distance',
#  'transactionType',
#  'productLabel',
#  'commercial',
#  'development',
#  'residential',
#  'students',
#  'auction',
#  'feesApply',
#  'feesApplyText',
#  'displaySize',
#  'showOnMap',
#  'propertyUrl',
#  'contactUrl',
#  'staticMapUrl',
#  'channel',
#  'firstVisibleDate',
#  'keywords',
#  'keywordMatchType',
#  'saved',
#  'hidden',
#  'onlineViewingsAvailable',
#  'displayStatus',
#  'formattedBranchName',
#  'addedOrReduced',
#  'isRecent',
#  'formattedDistance',
#  'hasBrandPlus',
#  'heading',
#  'enhancedListing',
#  'propertyTypeFullDescription']

# %% [markdown]
# **Remove duplicated property listings by IDs**

# %%
raw_data.duplicated(subset=['id']).value_counts()
"""
Duplicate IDs exist when the listing is also a featured listing at the top of any page. IDs should be unique.
"""
# Out:
# False    1023
# True       27
# dtype: int64
# '\nDuplicate IDs exist when the listing is also a featured listing at the top of any page. IDs should be unique.\n'

# %%
#Drop duplicates
raw_data.drop_duplicates(subset="id", inplace=True)
#Check for duplicates
raw_data.duplicated(subset=['id']).value_counts()
# Out:
# False    1023
# dtype: int64

# %% [markdown]
# **Grab only required columns**

# %%
#Rather than dropping, choose which columns to keep
df_subset = raw_data.loc[:, ["id", "bedrooms", "bathrooms", "location", "propertySubType", "price", "auction", "channel", "productLabel" ]]
print(df_subset.shape)
df_subset
# Out:
# (1023, 9)
#              id  bedrooms  bathrooms  \
# 0      89386117         4        3.0
# 1      76636641         6        0.0
# 2      86007409         4        2.0
# 3      73255458         2        2.0
# 4      88981993         4        2.0
# ...         ...       ...        ...
# 1045   96145934         3        1.0
# 1046  102112697         3        NaN
# 1047   99042143         3        2.0
# 1048   87124249         3        1.0
# 1049  101617700         3        NaN
#
#                                              location propertySubType  \
# 0     {'latitude': 51.338951, 'longitude': -0.262866}        Terraced
# 1      {'latitude': 51.34777, 'longitude': -0.242032}        Detached
# 2       {'latitude': 51.3791, 'longitude': -0.342057}        Detached
# 3     {'latitude': 51.365766, 'longitude': -0.367829}       Apartment
# 4     {'latitude': 51.355801, 'longitude': -0.300656}        Detached
# ...                                               ...             ...
# 1045  {'latitude': 51.398266, 'longitude': -0.234223}        Terraced
# 1046    {'latitude': 51.36223, 'longitude': -0.27247}        Detached
# 1047  {'latitude': 51.364906, 'longitude': -0.268977}   Semi-Detached
# 1048    {'latitude': 51.39715, 'longitude': -0.24427}  End of Terrace
# 1049    {'latitude': 51.36657, 'longitude': -0.30434}        Detached
#
#                                                                                                                                                                             price  \
# 0                {'amount': 575000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£575,000', 'displayPriceQualifier': 'Offers Over'}]}
# 1     {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Offers in Excess of'}]}
# 2     {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Offers in Region of'}]}
# 3             {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Guide Price'}]}
# 4             {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Guide Price'}]}
# ...                                                                                                                                                                           ...
# 1045                        {'amount': 560000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£560,000', 'displayPriceQualifier': ''}]}
# 1046                    {'amount': 555500, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£555,500', 'displayPriceQualifier': 'From'}]}
# 1047                        {'amount': 555000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£555,000', 'displayPriceQualifier': ''}]}
# 1048             {'amount': 550000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£550,000', 'displayPriceQualifier': 'Guide Price'}]}
# 1049     {'amount': 550000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£550,000', 'displayPriceQualifier': 'Offers in Excess of'}]}
#
#       auction channel  \
# 0       False     BUY
# 1       False     BUY
# 2       False     BUY
# 3       False     BUY
# 4       False     BUY
# ...       ...     ...
# 1045    False     BUY
# 1046    False     BUY
# 1047    False     BUY
# 1048    False     BUY
# 1049    False     BUY
#
#                                                                      productLabel
# 0                     {'productLabelText': 'Video Tour', 'spotlightLabel': False}
# 1                               {'productLabelText': '', 'spotlightLabel': False}
# 2     {'productLabelText': 'Potential to extend (STPP)', 'spotlightLabel': False}
# 3                {'productLabelText': 'Premium Listing', 'spotlightLabel': False}
# 4               {'productLabelText': 'Close to Station', 'spotlightLabel': False}
# ...                                                                           ...
# 1045            {'productLabelText': 'Close to Station', 'spotlightLabel': False}
# 1046                {'productLabelText': 'Assisted Move', 'spotlightLabel': True}
# 1047                {'productLabelText': 'Virtual Tour', 'spotlightLabel': False}
# 1048                    {'productLabelText': 'No Chain', 'spotlightLabel': False}
# 1049                            {'productLabelText': '', 'spotlightLabel': False}
#
# [1023 rows x 9 columns]

# %% [markdown]
# **Drop Auction properties**

# %%
auction_drop = df_subset.loc[df_subset["auction"] !=False]
auction_drop

print("number of auction listings dropped: ", auction_drop.shape[0])

df_subset = df_subset.drop(df_subset.index[auction_drop.index])
df_subset.shape


#Alt
# df_subset = df_subset[df_subset["auction"] == False]
# print("Deleted rows: " , df_subset[df_subset["auction"] != False].shape[0])
# print(df_subset.shape)
# Out:
#             id  bedrooms  bathrooms  \
# 649  102525533         4        2.0
#
#                                            location propertySubType  \
# 649  {'latitude': 51.35049, 'longitude': -0.255419}        Detached
#
#                                                                                                                                                                 price  \
# 649  {'amount': 650000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£650,000', 'displayPriceQualifier': 'Guide Price'}]}
#
#      auction channel  \
# 649     True     BUY
#
#                                                      productLabel
# 649  {'productLabelText': 'New Listing', 'spotlightLabel': False}
# number of auction listings dropped:  1
# (1022, 9)

# %% [markdown]
# **Drop any non-Buy properties**

# %%
print("Delete rows: " , df_subset[df_subset["channel"] != "BUY"].shape[0])
df_subset = df_subset[df_subset["channel"] == "BUY"]
print(df_subset.shape)
# Out:
# Delete rows:  0
# (1022, 9)

# %% [markdown]
# **Search and drop Null values**
#
# For now drop rows where the bathroom value is NaN.
# For next time: See if you can best approximate the number of bathrooms based on property type and number of bedrooms and maybe also price of property.

# %%
df_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1022 entries, 0 to 1049
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1022 non-null   int64
#  1   bedrooms         1022 non-null   int64
#  2   bathrooms        941 non-null    float64
#  3   location         1022 non-null   object
#  4   propertySubType  1022 non-null   object
#  5   price            1022 non-null   object
#  6   auction          1022 non-null   bool
#  7   channel          1022 non-null   object
#  8   productLabel     1022 non-null   object
# dtypes: bool(1), float64(1), int64(2), object(5)
# memory usage: 72.9+ KB

# %%
df_subset["bathrooms"].value_counts(dropna = False)
# Out:
# 2.0    506
# 1.0    263
# 3.0    125
# NaN     81
# 0.0     34
# 4.0     12
# 5.0      1
# Name: bathrooms, dtype: int64

# %%
df_subset["bathrooms"].value_counts(dropna = False, normalize = True)
# Out:
# 2.0    0.495108
# 1.0    0.257339
# 3.0    0.122309
# NaN    0.079256
# 0.0    0.033268
# 4.0    0.011742
# 5.0    0.000978
# Name: bathrooms, dtype: float64

# %%
df_subset.dropna(subset=["bathrooms"], inplace=True)
df_subset.shape
# Out:
# (941, 9)

# %%
df_subset
# Out:
#              id  bedrooms  bathrooms  \
# 0      89386117         4        3.0
# 1      76636641         6        0.0
# 2      86007409         4        2.0
# 3      73255458         2        2.0
# 4      88981993         4        2.0
# ...         ...       ...        ...
# 1043  101151050         4        3.0
# 1044   88759417         3        2.0
# 1045   96145934         3        1.0
# 1047   99042143         3        2.0
# 1048   87124249         3        1.0
#
#                                              location propertySubType  \
# 0     {'latitude': 51.338951, 'longitude': -0.262866}        Terraced
# 1      {'latitude': 51.34777, 'longitude': -0.242032}        Detached
# 2       {'latitude': 51.3791, 'longitude': -0.342057}        Detached
# 3     {'latitude': 51.365766, 'longitude': -0.367829}       Apartment
# 4     {'latitude': 51.355801, 'longitude': -0.300656}        Detached
# ...                                               ...             ...
# 1043  {'latitude': 51.375669, 'longitude': -0.483489}           House
# 1044   {'latitude': 51.342006, 'longitude': -0.26921}   Semi-Detached
# 1045  {'latitude': 51.398266, 'longitude': -0.234223}        Terraced
# 1047  {'latitude': 51.364906, 'longitude': -0.268977}   Semi-Detached
# 1048    {'latitude': 51.39715, 'longitude': -0.24427}  End of Terrace
#
#                                                                                                                                                                             price  \
# 0                {'amount': 575000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£575,000', 'displayPriceQualifier': 'Offers Over'}]}
# 1     {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Offers in Excess of'}]}
# 2     {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Offers in Region of'}]}
# 3             {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Guide Price'}]}
# 4             {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Guide Price'}]}
# ...                                                                                                                                                                           ...
# 1043                        {'amount': 560000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£560,000', 'displayPriceQualifier': ''}]}
# 1044             {'amount': 560000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£560,000', 'displayPriceQualifier': 'Guide Price'}]}
# 1045                        {'amount': 560000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£560,000', 'displayPriceQualifier': ''}]}
# 1047                        {'amount': 555000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£555,000', 'displayPriceQualifier': ''}]}
# 1048             {'amount': 550000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£550,000', 'displayPriceQualifier': 'Guide Price'}]}
#
#       auction channel  \
# 0       False     BUY
# 1       False     BUY
# 2       False     BUY
# 3       False     BUY
# 4       False     BUY
# ...       ...     ...
# 1043    False     BUY
# 1044    False     BUY
# 1045    False     BUY
# 1047    False     BUY
# 1048    False     BUY
#
#                                                                      productLabel
# 0                     {'productLabelText': 'Video Tour', 'spotlightLabel': False}
# 1                               {'productLabelText': '', 'spotlightLabel': False}
# 2     {'productLabelText': 'Potential to extend (STPP)', 'spotlightLabel': False}
# 3                {'productLabelText': 'Premium Listing', 'spotlightLabel': False}
# 4               {'productLabelText': 'Close to Station', 'spotlightLabel': False}
# ...                                                                           ...
# 1043                            {'productLabelText': '', 'spotlightLabel': False}
# 1044                  {'productLabelText': 'Video Tour', 'spotlightLabel': False}
# 1045            {'productLabelText': 'Close to Station', 'spotlightLabel': False}
# 1047                {'productLabelText': 'Virtual Tour', 'spotlightLabel': False}
# 1048                    {'productLabelText': 'No Chain', 'spotlightLabel': False}
#
# [941 rows x 9 columns]

# %% [markdown]
# **Drop auction and channel columns as no longer required**
#
# For practice, convert auction column to numerical binary}

# %%
#For practice, convert auction column to numerical binary
df_subset['auction'] = (df_subset['auction'] == 'TRUE').astype(int)
df_subset
# Out:
#              id  bedrooms  bathrooms  \
# 0      89386117         4        3.0
# 1      76636641         6        0.0
# 2      86007409         4        2.0
# 3      73255458         2        2.0
# 4      88981993         4        2.0
# ...         ...       ...        ...
# 1043  101151050         4        3.0
# 1044   88759417         3        2.0
# 1045   96145934         3        1.0
# 1047   99042143         3        2.0
# 1048   87124249         3        1.0
#
#                                              location propertySubType  \
# 0     {'latitude': 51.338951, 'longitude': -0.262866}        Terraced
# 1      {'latitude': 51.34777, 'longitude': -0.242032}        Detached
# 2       {'latitude': 51.3791, 'longitude': -0.342057}        Detached
# 3     {'latitude': 51.365766, 'longitude': -0.367829}       Apartment
# 4     {'latitude': 51.355801, 'longitude': -0.300656}        Detached
# ...                                               ...             ...
# 1043  {'latitude': 51.375669, 'longitude': -0.483489}           House
# 1044   {'latitude': 51.342006, 'longitude': -0.26921}   Semi-Detached
# 1045  {'latitude': 51.398266, 'longitude': -0.234223}        Terraced
# 1047  {'latitude': 51.364906, 'longitude': -0.268977}   Semi-Detached
# 1048    {'latitude': 51.39715, 'longitude': -0.24427}  End of Terrace
#
#                                                                                                                                                                             price  \
# 0                {'amount': 575000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£575,000', 'displayPriceQualifier': 'Offers Over'}]}
# 1     {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Offers in Excess of'}]}
# 2     {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Offers in Region of'}]}
# 3             {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Guide Price'}]}
# 4             {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Guide Price'}]}
# ...                                                                                                                                                                           ...
# 1043                        {'amount': 560000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£560,000', 'displayPriceQualifier': ''}]}
# 1044             {'amount': 560000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£560,000', 'displayPriceQualifier': 'Guide Price'}]}
# 1045                        {'amount': 560000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£560,000', 'displayPriceQualifier': ''}]}
# 1047                        {'amount': 555000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£555,000', 'displayPriceQualifier': ''}]}
# 1048             {'amount': 550000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£550,000', 'displayPriceQualifier': 'Guide Price'}]}
#
#       auction channel  \
# 0           0     BUY
# 1           0     BUY
# 2           0     BUY
# 3           0     BUY
# 4           0     BUY
# ...       ...     ...
# 1043        0     BUY
# 1044        0     BUY
# 1045        0     BUY
# 1047        0     BUY
# 1048        0     BUY
#
#                                                                      productLabel
# 0                     {'productLabelText': 'Video Tour', 'spotlightLabel': False}
# 1                               {'productLabelText': '', 'spotlightLabel': False}
# 2     {'productLabelText': 'Potential to extend (STPP)', 'spotlightLabel': False}
# 3                {'productLabelText': 'Premium Listing', 'spotlightLabel': False}
# 4               {'productLabelText': 'Close to Station', 'spotlightLabel': False}
# ...                                                                           ...
# 1043                            {'productLabelText': '', 'spotlightLabel': False}
# 1044                  {'productLabelText': 'Video Tour', 'spotlightLabel': False}
# 1045            {'productLabelText': 'Close to Station', 'spotlightLabel': False}
# 1047                {'productLabelText': 'Virtual Tour', 'spotlightLabel': False}
# 1048                    {'productLabelText': 'No Chain', 'spotlightLabel': False}
#
# [941 rows x 9 columns]

# %% [markdown]
# **Drop Auction and Channel columns as they are not required**

# %%
df_subset.drop(["auction", "channel"], inplace=True, axis=1)
df_subset
# Out:
#              id  bedrooms  bathrooms  \
# 0      89386117         4        3.0
# 1      76636641         6        0.0
# 2      86007409         4        2.0
# 3      73255458         2        2.0
# 4      88981993         4        2.0
# ...         ...       ...        ...
# 1043  101151050         4        3.0
# 1044   88759417         3        2.0
# 1045   96145934         3        1.0
# 1047   99042143         3        2.0
# 1048   87124249         3        1.0
#
#                                              location propertySubType  \
# 0     {'latitude': 51.338951, 'longitude': -0.262866}        Terraced
# 1      {'latitude': 51.34777, 'longitude': -0.242032}        Detached
# 2       {'latitude': 51.3791, 'longitude': -0.342057}        Detached
# 3     {'latitude': 51.365766, 'longitude': -0.367829}       Apartment
# 4     {'latitude': 51.355801, 'longitude': -0.300656}        Detached
# ...                                               ...             ...
# 1043  {'latitude': 51.375669, 'longitude': -0.483489}           House
# 1044   {'latitude': 51.342006, 'longitude': -0.26921}   Semi-Detached
# 1045  {'latitude': 51.398266, 'longitude': -0.234223}        Terraced
# 1047  {'latitude': 51.364906, 'longitude': -0.268977}   Semi-Detached
# 1048    {'latitude': 51.39715, 'longitude': -0.24427}  End of Terrace
#
#                                                                                                                                                                             price  \
# 0                {'amount': 575000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£575,000', 'displayPriceQualifier': 'Offers Over'}]}
# 1     {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Offers in Excess of'}]}
# 2     {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Offers in Region of'}]}
# 3             {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Guide Price'}]}
# 4             {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Guide Price'}]}
# ...                                                                                                                                                                           ...
# 1043                        {'amount': 560000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£560,000', 'displayPriceQualifier': ''}]}
# 1044             {'amount': 560000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£560,000', 'displayPriceQualifier': 'Guide Price'}]}
# 1045                        {'amount': 560000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£560,000', 'displayPriceQualifier': ''}]}
# 1047                        {'amount': 555000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£555,000', 'displayPriceQualifier': ''}]}
# 1048             {'amount': 550000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£550,000', 'displayPriceQualifier': 'Guide Price'}]}
#
#                                                                      productLabel
# 0                     {'productLabelText': 'Video Tour', 'spotlightLabel': False}
# 1                               {'productLabelText': '', 'spotlightLabel': False}
# 2     {'productLabelText': 'Potential to extend (STPP)', 'spotlightLabel': False}
# 3                {'productLabelText': 'Premium Listing', 'spotlightLabel': False}
# 4               {'productLabelText': 'Close to Station', 'spotlightLabel': False}
# ...                                                                           ...
# 1043                            {'productLabelText': '', 'spotlightLabel': False}
# 1044                  {'productLabelText': 'Video Tour', 'spotlightLabel': False}
# 1045            {'productLabelText': 'Close to Station', 'spotlightLabel': False}
# 1047                {'productLabelText': 'Virtual Tour', 'spotlightLabel': False}
# 1048                    {'productLabelText': 'No Chain', 'spotlightLabel': False}
#
# [941 rows x 7 columns]

# %% [markdown]
# **Using data in Location - Create a Lat and Long column**

# %%
#pd.json_normalize(df.location) is significantly faster than df.location.apply(pd.Series)

df_subset = pd.concat([df_subset.drop(['location'], axis=1), df_subset['location'].apply(pd.Series)], axis=1)
df_subset
# Out:
#              id  bedrooms  bathrooms propertySubType  \
# 0      89386117         4        3.0        Terraced
# 1      76636641         6        0.0        Detached
# 2      86007409         4        2.0        Detached
# 3      73255458         2        2.0       Apartment
# 4      88981993         4        2.0        Detached
# ...         ...       ...        ...             ...
# 1043  101151050         4        3.0           House
# 1044   88759417         3        2.0   Semi-Detached
# 1045   96145934         3        1.0        Terraced
# 1047   99042143         3        2.0   Semi-Detached
# 1048   87124249         3        1.0  End of Terrace
#
#                                                                                                                                                                             price  \
# 0                {'amount': 575000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£575,000', 'displayPriceQualifier': 'Offers Over'}]}
# 1     {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Offers in Excess of'}]}
# 2     {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Offers in Region of'}]}
# 3             {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Guide Price'}]}
# 4             {'amount': 1000000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£1,000,000', 'displayPriceQualifier': 'Guide Price'}]}
# ...                                                                                                                                                                           ...
# 1043                        {'amount': 560000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£560,000', 'displayPriceQualifier': ''}]}
# 1044             {'amount': 560000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£560,000', 'displayPriceQualifier': 'Guide Price'}]}
# 1045                        {'amount': 560000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£560,000', 'displayPriceQualifier': ''}]}
# 1047                        {'amount': 555000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£555,000', 'displayPriceQualifier': ''}]}
# 1048             {'amount': 550000, 'frequency': 'not specified', 'currencyCode': 'GBP', 'displayPrices': [{'displayPrice': '£550,000', 'displayPriceQualifier': 'Guide Price'}]}
#
#                                                                      productLabel  \
# 0                     {'productLabelText': 'Video Tour', 'spotlightLabel': False}
# 1                               {'productLabelText': '', 'spotlightLabel': False}
# 2     {'productLabelText': 'Potential to extend (STPP)', 'spotlightLabel': False}
# 3                {'productLabelText': 'Premium Listing', 'spotlightLabel': False}
# 4               {'productLabelText': 'Close to Station', 'spotlightLabel': False}
# ...                                                                           ...
# 1043                            {'productLabelText': '', 'spotlightLabel': False}
# 1044                  {'productLabelText': 'Video Tour', 'spotlightLabel': False}
# 1045            {'productLabelText': 'Close to Station', 'spotlightLabel': False}
# 1047                {'productLabelText': 'Virtual Tour', 'spotlightLabel': False}
# 1048                    {'productLabelText': 'No Chain', 'spotlightLabel': False}
#
#        latitude  longitude
# 0     51.338951  -0.262866
# 1     51.347770  -0.242032
# 2     51.379100  -0.342057
# 3     51.365766  -0.367829
# 4     51.355801  -0.300656
# ...         ...        ...
# 1043  51.375669  -0.483489
# 1044  51.342006  -0.269210
# 1045  51.398266  -0.234223
# 1047  51.364906  -0.268977
# 1048  51.397150  -0.244270
#
# [941 rows x 8 columns]

# %%
df_subset = pd.concat([df_subset.drop(['price'], axis=1), df_subset['price'].apply(pd.Series)], axis=1)
df_subset.drop(["frequency", "currencyCode", "displayPrices"], axis =1, inplace=True)
df_subset
# Out:
#              id  bedrooms  bathrooms propertySubType  \
# 0      89386117         4        3.0        Terraced
# 1      76636641         6        0.0        Detached
# 2      86007409         4        2.0        Detached
# 3      73255458         2        2.0       Apartment
# 4      88981993         4        2.0        Detached
# ...         ...       ...        ...             ...
# 1043  101151050         4        3.0           House
# 1044   88759417         3        2.0   Semi-Detached
# 1045   96145934         3        1.0        Terraced
# 1047   99042143         3        2.0   Semi-Detached
# 1048   87124249         3        1.0  End of Terrace
#
#                                                                      productLabel  \
# 0                     {'productLabelText': 'Video Tour', 'spotlightLabel': False}
# 1                               {'productLabelText': '', 'spotlightLabel': False}
# 2     {'productLabelText': 'Potential to extend (STPP)', 'spotlightLabel': False}
# 3                {'productLabelText': 'Premium Listing', 'spotlightLabel': False}
# 4               {'productLabelText': 'Close to Station', 'spotlightLabel': False}
# ...                                                                           ...
# 1043                            {'productLabelText': '', 'spotlightLabel': False}
# 1044                  {'productLabelText': 'Video Tour', 'spotlightLabel': False}
# 1045            {'productLabelText': 'Close to Station', 'spotlightLabel': False}
# 1047                {'productLabelText': 'Virtual Tour', 'spotlightLabel': False}
# 1048                    {'productLabelText': 'No Chain', 'spotlightLabel': False}
#
#        latitude  longitude   amount
# 0     51.338951  -0.262866   575000
# 1     51.347770  -0.242032  1000000
# 2     51.379100  -0.342057  1000000
# 3     51.365766  -0.367829  1000000
# 4     51.355801  -0.300656  1000000
# ...         ...        ...      ...
# 1043  51.375669  -0.483489   560000
# 1044  51.342006  -0.269210   560000
# 1045  51.398266  -0.234223   560000
# 1047  51.364906  -0.268977   555000
# 1048  51.397150  -0.244270   550000
#
# [941 rows x 8 columns]

# %%
df_subset = pd.concat([df_subset.drop(['productLabel'], axis=1), df_subset['productLabel'].apply(pd.Series)], axis=1)
df_subset.drop(["spotlightLabel"], axis =1, inplace=True)
df_subset
# Out:
#              id  bedrooms  bathrooms propertySubType   latitude  longitude  \
# 0      89386117         4        3.0        Terraced  51.338951  -0.262866
# 1      76636641         6        0.0        Detached  51.347770  -0.242032
# 2      86007409         4        2.0        Detached  51.379100  -0.342057
# 3      73255458         2        2.0       Apartment  51.365766  -0.367829
# 4      88981993         4        2.0        Detached  51.355801  -0.300656
# ...         ...       ...        ...             ...        ...        ...
# 1043  101151050         4        3.0           House  51.375669  -0.483489
# 1044   88759417         3        2.0   Semi-Detached  51.342006  -0.269210
# 1045   96145934         3        1.0        Terraced  51.398266  -0.234223
# 1047   99042143         3        2.0   Semi-Detached  51.364906  -0.268977
# 1048   87124249         3        1.0  End of Terrace  51.397150  -0.244270
#
#        amount            productLabelText
# 0      575000                  Video Tour
# 1     1000000
# 2     1000000  Potential to extend (STPP)
# 3     1000000             Premium Listing
# 4     1000000            Close to Station
# ...       ...                         ...
# 1043   560000
# 1044   560000                  Video Tour
# 1045   560000            Close to Station
# 1047   555000                Virtual Tour
# 1048   550000                    No Chain
#
# [941 rows x 8 columns]

# %%
df_subset.rename(columns={"amount":"Price", "productLabelText":"Specials"}, inplace=True)

# %%
df_subset
# Out:
#              id  bedrooms  bathrooms propertySubType   latitude  longitude  \
# 0      89386117         4        3.0        Terraced  51.338951  -0.262866
# 1      76636641         6        0.0        Detached  51.347770  -0.242032
# 2      86007409         4        2.0        Detached  51.379100  -0.342057
# 3      73255458         2        2.0       Apartment  51.365766  -0.367829
# 4      88981993         4        2.0        Detached  51.355801  -0.300656
# ...         ...       ...        ...             ...        ...        ...
# 1043  101151050         4        3.0           House  51.375669  -0.483489
# 1044   88759417         3        2.0   Semi-Detached  51.342006  -0.269210
# 1045   96145934         3        1.0        Terraced  51.398266  -0.234223
# 1047   99042143         3        2.0   Semi-Detached  51.364906  -0.268977
# 1048   87124249         3        1.0  End of Terrace  51.397150  -0.244270
#
#         Price                    Specials
# 0      575000                  Video Tour
# 1     1000000
# 2     1000000  Potential to extend (STPP)
# 3     1000000             Premium Listing
# 4     1000000            Close to Station
# ...       ...                         ...
# 1043   560000
# 1044   560000                  Video Tour
# 1045   560000            Close to Station
# 1047   555000                Virtual Tour
# 1048   550000                    No Chain
#
# [941 rows x 8 columns]

# %% [markdown]
# **Price per Bedroom**

# %%
df_subset["Price/Bedroom"] = (df_subset["Price"]/df_subset["bedrooms"]).round(0)
df_subset
# Out:
#              id  bedrooms  bathrooms propertySubType   latitude  longitude  \
# 0      89386117         4        3.0        Terraced  51.338951  -0.262866
# 1      76636641         6        0.0        Detached  51.347770  -0.242032
# 2      86007409         4        2.0        Detached  51.379100  -0.342057
# 3      73255458         2        2.0       Apartment  51.365766  -0.367829
# 4      88981993         4        2.0        Detached  51.355801  -0.300656
# ...         ...       ...        ...             ...        ...        ...
# 1043  101151050         4        3.0           House  51.375669  -0.483489
# 1044   88759417         3        2.0   Semi-Detached  51.342006  -0.269210
# 1045   96145934         3        1.0        Terraced  51.398266  -0.234223
# 1047   99042143         3        2.0   Semi-Detached  51.364906  -0.268977
# 1048   87124249         3        1.0  End of Terrace  51.397150  -0.244270
#
#         Price                    Specials  Price/Bedroom
# 0      575000                  Video Tour       143750.0
# 1     1000000                                   166667.0
# 2     1000000  Potential to extend (STPP)       250000.0
# 3     1000000             Premium Listing       500000.0
# 4     1000000            Close to Station       250000.0
# ...       ...                         ...            ...
# 1043   560000                                   140000.0
# 1044   560000                  Video Tour       186667.0
# 1045   560000            Close to Station       186667.0
# 1047   555000                Virtual Tour       185000.0
# 1048   550000                    No Chain       183333.0
#
# [941 rows x 9 columns]

# %% [markdown]
# **Get postcode from Long and Lat**

# %%
#Get a list of all possible KT postcodes

# %%
URL_KT = ("https://en.wikipedia.org/wiki/KT_postcode_area")
results = requests.get(URL_KT).text
soup = BeautifulSoup(results, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    KT postcode area - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"YD43gcFEmJ9X9UocB9pDVQAAAQ4","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"KT_postcode_area","wgTitle":"KT postcode area","wgCurRevisionId":983530632,"wgRevisionId":983530632,"wgArticleId":1434954,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description matches Wikidata","Use dmy dates from November 2019","Articles using KML from Wikidata","Short description is different from Wikidata","Pages using infobox settlement with bad settlement type","Postcode areas covering London",
# "Postcode areas covering South East England","Media and communications in the Royal Borough of Kingston upon Thames","Media and communications in the London Borough of Sutton","Media and communications in the London Borough of Richmond upon Thames","Epsom and Ewell"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"KT_postcode_area","wgRelevantArticleId":1434954,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgPopupsConflictsWithRefTooltipsGadget":!0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia"
# ,"wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgWikibaseItemId":"Q6339413"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups",
# "ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});
#   </script>
#   <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.36.0-wmf.32" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/d/d9/United_Kingdom_adm_location_map.svg/1200px-United_Kingdom_adm_location_map.svg.png" property="og:image"/>
#   <meta content="KT postcode area" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <link href="//upload.wikimedia.org" rel="preconnect"/>
#   <link href="//en.m.wikipedia.org/wiki/KT_postcode_area" media="only screen and (max-width: 720px)" rel="alternate"/>
#   <link href="/w/index.php?title=KT_postcode_area&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
#   <link href="/w/index.php?title=KT_postcode_area&amp;action=edit" rel="edit" title="Edit this page"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="https://en.wikipedia.org/wiki/KT_postcode_area" rel="canonical"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-KT_postcode_area rootpage-KT_postcode_area skin-vector action-view skin-vector-legacy">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div class="mw-body-content" id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators mw-body-content">
#    </div>
#    <h1 class="firstHeading" id="firstHeading">
#     KT postcode area
#    </h1>
#    <div class="mw-body-content" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      From Wikipedia, the free encyclopedia
#     </div>
#     <div id="contentSub">
#     </div>
#     <div id="contentSub2">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Jump to navigation
#     </a>
#     <a class="mw-jump-link" href="#searchInput">
#      Jump to search
#     </a>
#     <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#      <div class="mw-parser-output">
#       <div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">
#        Postcode area within the United Kingdom
#       </div>
#       <div class="hatnote navigation-not-searchable" role="note">
#        "KT4" redirects here. For the tram type, see
#        <a href="/wiki/Tatra_KT4" title="Tatra KT4">
#         Tatra KT4
#        </a>
#        .
#       </div>
#       <p class="mw-empty-elt">
#       </p>
#       <p>
#        <span style="font-size: small;">
#         <span id="coordinates">
#          <b>
#           Postcode district boundaries
#          </b>
#          :
#         </span>
#        </span>
#       </p>
#       <div class="kmldata" data-server="en.wikipedia.org" style="display:none;" title="Template:Attached KML/KT postcode area">
#        <a href="/wiki/Template:Attached_KML/KT_postcode_area" title="Template:Attached KML/KT postcode area">
#         Template:Attached KML/KT postcode area
#        </a>
#       </div>
#       <div style="display:none;" title="KML &amp; Wikidata">
#        KML is from Wikidata
#       </div>
#       <div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">
#        United Kingdom postcode area
#       </div>
#       <table class="infobox geography vcard" style="width:22em;width:23em">
#        <tbody>
#         <tr>
#          <th colspan="2" style="text-align:center;font-size:125%;font-weight:bold;font-size:1.25em; white-space:nowrap">
#           <div class="fn org" style="display:inline">
#            Kingston upon Thames
#           </div>
#          </th>
#         </tr>
#         <tr>
#          <td colspan="2" style="text-align:center;background-color:#cddeff; font-weight:bold;">
#           <div class="category">
#            <a href="/wiki/List_of_postcode_areas_in_the_United_Kingdom" title="List of postcode areas in the United Kingdom">
#             United Kingdom postcode area
#            </a>
#           </div>
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <td colspan="2" style="text-align:center">
#           <style data-mw-deduplicate="TemplateStyles:r997900035">
#            .mw-parser-output .locmap .od{position:absolute}.mw-parser-output .locmap .id{position:absolute;line-height:0}.mw-parser-output .locmap .l0{font-size:0;position:absolute}.mw-parser-output .locmap .pv{line-height:110%;position:absolute;text-align:center}.mw-parser-output .locmap .pl{line-height:110%;position:absolute;top:-0.75em;text-align:right}.mw-parser-output .locmap .pr{line-height:110%;position:absolute;top:-0.75em;text-align:left}.mw-parser-output .locmap .pv>div{display:inline;padding:1px}.mw-parser-output .locmap .pl>div{display:inline;padding:1px;float:right}.mw-parser-output .locmap .pr>div{display:inline;padding:1px;float:left}
#           </style>
#           <div class="center">
#            <div class="locmap" style="width:250px;float:none;clear:both;margin-left:auto;margin-right:auto">
#             <div style="width:250px;padding:0">
#              <div style="position:relative;width:250px">
#               <a class="image" href="/wiki/File:United_Kingdom_adm_location_map.svg" title="KT is located in the United Kingdom">
#                <img alt="KT is located in the United Kingdom" data-file-height="1369" data-file-width="886" decoding="async" height="386" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/United_Kingdom_adm_location_map.svg/250px-United_Kingdom_adm_location_map.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/United_Kingdom_adm_location_map.svg/375px-United_Kingdom_adm_location_map.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d9/United_Kingdom_adm_location_map.svg/500px-United_Kingdom_adm_location_map.svg.png 2x" width="250"/>
#               </a>
#               <div class="od" style="top:80.35%;left:80.727%">
#                <div class="id" style="left:-3px;top:-3px">
#                 <img alt="KT" data-file-height="64" data-file-width="64" decoding="async" height="6" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/6px-Red_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/9px-Red_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/12px-Red_pog.svg.png 2x" title="KT" width="6"/>
#                </div>
#                <div class="pr" style="font-size:91%;width:6em;left:4px">
#                 <div>
#                  KT
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div style="padding-top:0.2em">
#              </div>
#             </div>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr class="mergedbottomrow">
#          <td colspan="2" style="text-align:center">
#           Coordinates:
#           <style data-mw-deduplicate="TemplateStyles:r994658806">
#            .mw-parser-output .geo-default,.mw-parser-output .geo-dms,.mw-parser-output .geo-dec{display:inline}.mw-parser-output .geo-nondefault,.mw-parser-output .geo-multi-punct{display:none}.mw-parser-output .longitude,.mw-parser-output .latitude{white-space:nowrap}
#           </style>
#           <span class="plainlinks nourlexpansion">
#            <a class="external text" href="//geohack.toolforge.org/geohack.php?pagename=KT_postcode_area&amp;params=51.358_N_0.344_W_type:city_region:GB" rel="nofollow">
#             <span class="geo-nondefault">
#              <span class="geo-dms" title="Maps, aerial photos, and other data for this location">
#               <span class="latitude">
#                51°21′29″N
#               </span>
#               <span class="longitude">
#                0°20′38″W
#               </span>
#              </span>
#             </span>
#             <span class="geo-multi-punct">
#              ﻿ / ﻿
#             </span>
#             <span class="geo-default">
#              <span class="geo-dec" title="Maps, aerial photos, and other data for this location">
#               51.358°N 0.344°W
#              </span>
#              <span style="display:none">
#               ﻿ /
#               <span class="geo">
#                51.358; -0.344
#               </span>
#              </span>
#             </span>
#            </a>
#           </span>
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <th scope="row">
#           Country
#          </th>
#          <td>
#           United Kingdom
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <th scope="row">
#           <a href="/wiki/List_of_postcode_areas_in_the_United_Kingdom" title="List of postcode areas in the United Kingdom">
#            Postcode area
#           </a>
#          </th>
#          <td class="adr">
#           <div class="postal-code">
#            KT
#           </div>
#          </td>
#         </tr>
#         <tr class="mergedbottomrow">
#          <th scope="row">
#           Postcode area name
#          </th>
#          <td class="adr">
#           <div class="postal-code">
#            Kingston upon Thames
#           </div>
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <th scope="row">
#           <a href="/wiki/Post_town" title="Post town">
#            Post towns
#           </a>
#          </th>
#          <td>
#           19
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           <a href="/wiki/List_of_postcode_districts_in_the_United_Kingdom" title="List of postcode districts in the United Kingdom">
#            Postcode districts
#           </a>
#          </th>
#          <td>
#           24
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           Postcode sectors
#          </th>
#          <td>
#           92
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           Postcodes (live)
#          </th>
#          <td>
#           14,168
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           Postcodes (total)
#          </th>
#          <td>
#           22,311
#          </td>
#         </tr>
#         <tr>
#          <td colspan="2" style="text-align:center;text-align:left;">
#           Statistics as at May 2020
#           <sup class="reference" id="cite_ref-1">
#            <a href="#cite_note-1">
#             [1]
#            </a>
#           </sup>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <p>
#        The
#        <b>
#         KT postcode area
#        </b>
#        , also known as the
#        <b>
#         Kingston upon Thames postcode area
#        </b>
#        ,
#        <sup class="reference" id="cite_ref-2">
#         <a href="#cite_note-2">
#          [2]
#         </a>
#        </sup>
#        is a group of 24 postcode districts in
#        <a href="/wiki/England" title="England">
#         England
#        </a>
#        , within 19
#        <a href="/wiki/Post_town" title="Post town">
#         post towns
#        </a>
#        . These cover parts of southwestern
#        <a href="/wiki/Greater_London" title="Greater London">
#         Greater London
#        </a>
#        and northern
#        <a href="/wiki/Surrey" title="Surrey">
#         Surrey
#        </a>
#        .
#       </p>
#       <p>
#        Mail for this area is sorted at the Jubilee Mail Centre in
#        <a href="/wiki/Hounslow" title="Hounslow">
#         Hounslow
#        </a>
#        . In Greater London the area covers most of the
#        <a href="/wiki/Royal_Borough_of_Kingston_upon_Thames" title="Royal Borough of Kingston upon Thames">
#         Royal Borough of Kingston upon Thames
#        </a>
#        and small parts of the boroughs of
#        <a href="/wiki/London_Borough_of_Richmond_upon_Thames" title="London Borough of Richmond upon Thames">
#         Richmond upon Thames
#        </a>
#        ,
#        <a href="/wiki/London_Borough_of_Merton" title="London Borough of Merton">
#         Merton
#        </a>
#        and
#        <a href="/wiki/London_Borough_of_Sutton" title="London Borough of Sutton">
#         Sutton
#        </a>
#        , while in Surrey it covers virtually all of the
#        <a href="/wiki/Borough_of_Elmbridge" title="Borough of Elmbridge">
#         borough of Elmbridge
#        </a>
#        , most of the borough of
#        <a href="/wiki/Epsom_and_Ewell" title="Epsom and Ewell">
#         Epsom and Ewell
#        </a>
#        , the northwestern part of the borough of
#        <a href="/wiki/Reigate_and_Banstead" title="Reigate and Banstead">
#         Reigate and Banstead
#        </a>
#        , the northern part of the
#        <a href="/wiki/Mole_Valley" title="Mole Valley">
#         Mole Valley
#        </a>
#        district, the northeastern parts of the boroughs of
#        <a href="/wiki/Borough_of_Guildford" title="Borough of Guildford">
#         Guildford
#        </a>
#        and
#        <a href="/wiki/Borough_of_Woking" title="Borough of Woking">
#         Woking
#        </a>
#        and the southern part of the
#        <a href="/wiki/Borough_of_Runnymede" title="Borough of Runnymede">
#         borough of Runnymede
#        </a>
#        , as well as a very small part of the
#        <a href="/wiki/Borough_of_Spelthorne" title="Borough of Spelthorne">
#         borough of Spelthorne
#        </a>
#        .
#       </p>
#       <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation">
#        <input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/>
#        <div class="toctitle" dir="ltr" lang="en">
#         <h2 id="mw-toc-heading">
#          Contents
#         </h2>
#         <span class="toctogglespan">
#          <label class="toctogglelabel" for="toctogglecheckbox">
#          </label>
#         </span>
#        </div>
#        <ul>
#         <li class="toclevel-1 tocsection-1">
#          <a href="#Coverage">
#           <span class="tocnumber">
#            1
#           </span>
#           <span class="toctext">
#            Coverage
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-2">
#          <a href="#Map">
#           <span class="tocnumber">
#            2
#           </span>
#           <span class="toctext">
#            Map
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-3">
#          <a href="#See_also">
#           <span class="tocnumber">
#            3
#           </span>
#           <span class="toctext">
#            See also
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-4">
#          <a href="#References">
#           <span class="tocnumber">
#            4
#           </span>
#           <span class="toctext">
#            References
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-5">
#          <a href="#External_links">
#           <span class="tocnumber">
#            5
#           </span>
#           <span class="toctext">
#            External links
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div style="clear:both;">
#       </div>
#       <h2>
#        <span class="mw-headline" id="Coverage">
#         Coverage
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=KT_postcode_area&amp;action=edit&amp;section=1" title="Edit section: Coverage">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <p>
#        The approximate coverage of the postcode districts:
#       </p>
#       <table class="wikitable sortable" style="font-size:95%">
#        <tbody>
#         <tr style="white-space:nowrap">
#          <th>
#           Postcode district
#          </th>
#          <th>
#           <a href="/wiki/Post_town" title="Post town">
#            Post town
#           </a>
#          </th>
#          <th>
#           Coverage
#          </th>
#          <th>
#           Local authority area(s)
#          </th>
#         </tr>
#         <tr>
#          <th>
#           KT1
#          </th>
#          <td>
#           KINGSTON UPON THAMES
#          </td>
#          <td>
#           <a href="/wiki/Kingston_upon_Thames" title="Kingston upon Thames">
#            Kingston upon Thames
#           </a>
#           ,
#           <a href="/wiki/Hampton_Wick" title="Hampton Wick">
#            Hampton Wick
#           </a>
#           , part of
#           <a href="/wiki/Norbiton" title="Norbiton">
#            Norbiton
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Royal_Borough_of_Kingston_upon_Thames" title="Royal Borough of Kingston upon Thames">
#            Kingston upon Thames
#           </a>
#           ,
#           <a href="/wiki/London_Borough_of_Richmond_upon_Thames" title="London Borough of Richmond upon Thames">
#            Richmond upon Thames
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT2
#          </th>
#          <td>
#           KINGSTON UPON THAMES
#          </td>
#          <td>
#           Kingston upon Thames,
#           <a href="/wiki/Canbury" title="Canbury">
#            Canbury
#           </a>
#           ,
#           <a href="/wiki/Coombe,_Kingston_upon_Thames" title="Coombe, Kingston upon Thames">
#            Coombe
#           </a>
#           , part of
#           <a href="/wiki/Norbiton" title="Norbiton">
#            Norbiton
#           </a>
#          </td>
#          <td>
#           Kingston upon Thames, Richmond upon Thames
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT3
#          </th>
#          <td>
#           NEW MALDEN
#          </td>
#          <td>
#           <a href="/wiki/Motspur_Park" title="Motspur Park">
#            Motspur Park
#           </a>
#           ,
#           <a href="/wiki/New_Malden" title="New Malden">
#            New Malden
#           </a>
#           , part of
#           <a href="/wiki/Old_Malden" title="Old Malden">
#            Old Malden
#           </a>
#          </td>
#          <td>
#           Kingston upon Thames,
#           <a href="/wiki/London_Borough_of_Merton" title="London Borough of Merton">
#            Merton
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT4
#          </th>
#          <td>
#           WORCESTER PARK
#          </td>
#          <td>
#           <a href="/wiki/Worcester_Park" title="Worcester Park">
#            Worcester Park
#           </a>
#           ,
#           <a href="/wiki/Cuddington,_Surrey" title="Cuddington, Surrey">
#            Cuddington
#           </a>
#           , part of
#           <a href="/wiki/Old_Malden" title="Old Malden">
#            Old Malden
#           </a>
#           ,
#           <a href="/wiki/Stoneleigh,_Surrey" title="Stoneleigh, Surrey">
#            Stoneleigh
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/London_Borough_of_Sutton" title="London Borough of Sutton">
#            Sutton
#           </a>
#           ,
#           <a href="/wiki/Epsom_and_Ewell" title="Epsom and Ewell">
#            Epsom and Ewell
#           </a>
#           , Kingston upon Thames, Merton
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT5
#          </th>
#          <td>
#           SURBITON
#          </td>
#          <td>
#           <a href="/wiki/Berrylands" title="Berrylands">
#            Berrylands
#           </a>
#           , part of
#           <a href="/wiki/Surbiton" title="Surbiton">
#            Surbiton
#           </a>
#           , part of
#           <a href="/wiki/Tolworth" title="Tolworth">
#            Tolworth
#           </a>
#          </td>
#          <td>
#           Kingston upon Thames
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT6
#          </th>
#          <td>
#           SURBITON
#          </td>
#          <td>
#           <a href="/wiki/Surbiton" title="Surbiton">
#            Surbiton
#           </a>
#           ,
#           <a href="/wiki/Tolworth" title="Tolworth">
#            Tolworth
#           </a>
#           , part of
#           <a href="/wiki/Long_Ditton" title="Long Ditton">
#            Long Ditton
#           </a>
#           ,
#           <a href="/wiki/Seething_Wells" title="Seething Wells">
#            Seething Wells
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Kingston_upon_Thames" title="Kingston upon Thames">
#            Kingston upon Thames
#           </a>
#           ,
#           <a href="/wiki/Borough_of_Elmbridge" title="Borough of Elmbridge">
#            Elmbridge
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT7
#          </th>
#          <td>
#           THAMES DITTON
#          </td>
#          <td>
#           part of
#           <a href="/wiki/Long_Ditton" title="Long Ditton">
#            Long Ditton
#           </a>
#           ,
#           <a href="/wiki/Thames_Ditton" title="Thames Ditton">
#            Thames Ditton
#           </a>
#           , part of
#           <a href="/wiki/Weston_Green" title="Weston Green">
#            Weston Green
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Kingston_upon_Thames" title="Kingston upon Thames">
#            Kingston upon Thames
#           </a>
#           ,
#           <a href="/wiki/Borough_of_Elmbridge" title="Borough of Elmbridge">
#            Elmbridge
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT8
#          </th>
#          <td>
#           EAST MOLESEY; WEST MOLESEY
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/East_Molesey" title="East Molesey">
#            East Molesey
#           </a>
#           ,
#           <a class="mw-redirect" href="/wiki/West_Molesey" title="West Molesey">
#            West Molesey
#           </a>
#           ,
#           <a href="/wiki/Hampton_Court_Palace" title="Hampton Court Palace">
#            Hampton Court Palace and part of its Park
#           </a>
#           ; 1.5 Thames islands, part of
#           <a href="/wiki/Bushy_Park" title="Bushy Park">
#            Bushy Park
#           </a>
#           , Hampton Court neighbourhood,
#           <a href="/wiki/Hampton,_London" title="Hampton, London">
#            Hampton
#           </a>
#          </td>
#          <td>
#           Elmbridge, Richmond upon Thames
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT9
#          </th>
#          <td>
#           CHESSINGTON
#          </td>
#          <td>
#           <a href="/wiki/Chessington" title="Chessington">
#            Chessington
#           </a>
#           including
#           <a href="/wiki/Malden_Rushett" title="Malden Rushett">
#            Malden Rushett
#           </a>
#           ,
#           <a href="/wiki/Hook,_London" title="Hook, London">
#            Hook
#           </a>
#           , part of Long Ditton
#          </td>
#          <td>
#           Kingston upon Thames; Elmbridge
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT10
#          </th>
#          <td>
#           ESHER
#          </td>
#          <td>
#           <a href="/wiki/Esher" title="Esher">
#            Esher
#           </a>
#           ,
#           <a href="/wiki/Claygate" title="Claygate">
#            Claygate
#           </a>
#           ,
#           <a href="/wiki/Hinchley_Wood" title="Hinchley Wood">
#            Hinchley Wood
#           </a>
#           , part of
#           <a href="/wiki/Weston_Green" title="Weston Green">
#            Weston Green
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Borough_of_Elmbridge" title="Borough of Elmbridge">
#            Elmbridge
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT11
#          </th>
#          <td>
#           COBHAM
#          </td>
#          <td>
#           <a href="/wiki/Cobham,_Surrey" title="Cobham, Surrey">
#            Cobham
#           </a>
#           ,
#           <a href="/wiki/Stoke_d%27Abernon" title="Stoke d'Abernon">
#            Stoke d'Abernon
#           </a>
#           ,
#           <a href="/wiki/Downside,_Surrey" title="Downside, Surrey">
#            Downside
#           </a>
#           ,
#           <a href="/wiki/Hatchford" title="Hatchford">
#            Hatchford
#           </a>
#           , parts of
#           <a href="/wiki/Wisley" title="Wisley">
#            Wisley
#           </a>
#           ,
#           <a href="/wiki/Ockham,_Surrey" title="Ockham, Surrey">
#            Ockham
#           </a>
#           and
#           <a href="/wiki/Hersham" title="Hersham">
#            Hersham
#           </a>
#          </td>
#          <td>
#           Elmbridge,
#           <a href="/wiki/Borough_of_Guildford" title="Borough of Guildford">
#            Guildford
#           </a>
#           ,
#           <a href="/wiki/Mole_Valley" title="Mole Valley">
#            Mole Valley
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT12
#          </th>
#          <td>
#           WALTON-ON-THAMES
#          </td>
#          <td>
#           <a href="/wiki/Walton-on-Thames" title="Walton-on-Thames">
#            Walton-on-Thames
#           </a>
#           ,
#           <a href="/wiki/Hersham" title="Hersham">
#            Hersham
#           </a>
#           ,
#           <a href="/wiki/Whiteley_Village" title="Whiteley Village">
#            Whiteley Village
#           </a>
#          </td>
#          <td>
#           Elmbridge
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT13
#          </th>
#          <td>
#           WEYBRIDGE
#          </td>
#          <td>
#           <a href="/wiki/Weybridge" title="Weybridge">
#            Weybridge
#           </a>
#           ,
#           <a href="/wiki/Oatlands,_Surrey" title="Oatlands, Surrey">
#            Oatlands
#           </a>
#           ,
#           <a class="mw-redirect" href="/wiki/Saint_George%27s_Hill" title="Saint George's Hill">
#            Saint George's Hill
#           </a>
#           ,
#           <a href="/wiki/Addlestone#Hamm_Court" title="Addlestone">
#            Hamm Court
#           </a>
#          </td>
#          <td>
#           Elmbridge,
#           <a href="/wiki/Borough_of_Runnymede" title="Borough of Runnymede">
#            Runnymede
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT14
#          </th>
#          <td>
#           WEST BYFLEET
#          </td>
#          <td>
#           <a href="/wiki/Byfleet" title="Byfleet">
#            Byfleet
#           </a>
#           ,
#           <a href="/wiki/West_Byfleet" title="West Byfleet">
#            West Byfleet
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Borough_of_Woking" title="Borough of Woking">
#            Woking
#           </a>
#           , Elmbridge, Runnymede
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT15
#          </th>
#          <td>
#           ADDLESTONE
#          </td>
#          <td>
#           <a href="/wiki/Addlestone" title="Addlestone">
#            Addlestone
#           </a>
#           ,
#           <a href="/wiki/New_Haw" title="New Haw">
#            New Haw
#           </a>
#           ,
#           <a href="/wiki/Woodham,_Surrey" title="Woodham, Surrey">
#            Woodham
#           </a>
#          </td>
#          <td>
#           Runnymede, Woking
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT16
#          </th>
#          <td>
#           CHERTSEY
#          </td>
#          <td>
#           <a href="/wiki/Chertsey" title="Chertsey">
#            Chertsey
#           </a>
#           ,
#           <a href="/wiki/Ottershaw" title="Ottershaw">
#            Ottershaw
#           </a>
#           ,
#           <a href="/wiki/Longcross" title="Longcross">
#            Longcross
#           </a>
#           ,
#           <a href="/wiki/Lyne,_Surrey" title="Lyne, Surrey">
#            Lyne
#           </a>
#           ,
#           <a href="/wiki/Dumsey_Meadow" title="Dumsey Meadow">
#            Dumsey Meadow
#           </a>
#           in
#           <a href="/wiki/Littleton,_Spelthorne" title="Littleton, Spelthorne">
#            Littleton
#           </a>
#          </td>
#          <td>
#           Runnymede,
#           <a href="/wiki/Borough_of_Spelthorne" title="Borough of Spelthorne">
#            Spelthorne
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT17
#          </th>
#          <td>
#           EPSOM
#          </td>
#          <td>
#           <a href="/wiki/Epsom" title="Epsom">
#            Epsom
#           </a>
#           ,
#           <a href="/wiki/Ewell" title="Ewell">
#            Ewell
#           </a>
#           ,
#           <a href="/wiki/Stoneleigh,_Surrey" title="Stoneleigh, Surrey">
#            Stoneleigh
#           </a>
#          </td>
#          <td>
#           Epsom and Ewell,
#           <a href="/wiki/Reigate_and_Banstead" title="Reigate and Banstead">
#            Reigate and Banstead
#           </a>
#           , Sutton
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT18
#          </th>
#          <td>
#           EPSOM
#          </td>
#          <td>
#           <a href="/wiki/Epsom" title="Epsom">
#            Epsom
#           </a>
#           ,
#           <a href="/wiki/Tattenham_Corner" title="Tattenham Corner">
#            Tattenham Corner
#           </a>
#           ,
#           <a href="/wiki/Headley,_Surrey" title="Headley, Surrey">
#            Headley
#           </a>
#           ,
#           <a href="/wiki/Langley_Vale" title="Langley Vale">
#            Langley Vale
#           </a>
#          </td>
#          <td>
#           Epsom and Ewell, Mole Valley, Reigate and Banstead
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT19
#          </th>
#          <td>
#           EPSOM
#          </td>
#          <td>
#           <a href="/wiki/Epsom" title="Epsom">
#            Epsom
#           </a>
#           , West Ewell,
#           <a href="/wiki/Stoneleigh,_Surrey" title="Stoneleigh, Surrey">
#            Stoneleigh
#           </a>
#           ,
#           <a class="mw-redirect" href="/wiki/Horton,_Surrey" title="Horton, Surrey">
#            Horton
#           </a>
#           , Longmead
#          </td>
#          <td>
#           Epsom and Ewell
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT20
#          </th>
#          <td>
#           TADWORTH
#          </td>
#          <td>
#           <a href="/wiki/Tadworth" title="Tadworth">
#            Tadworth
#           </a>
#           ,
#           <a href="/wiki/Kingswood,_Surrey" title="Kingswood, Surrey">
#            Kingswood
#           </a>
#           ,
#           <a href="/wiki/Lower_Kingswood" title="Lower Kingswood">
#            Lower Kingswood
#           </a>
#           ,
#           <a href="/wiki/Walton-on-the-Hill" title="Walton-on-the-Hill">
#            Walton-on-the-Hill
#           </a>
#           ,
#           <a href="/wiki/Burgh_Heath" title="Burgh Heath">
#            Burgh Heath
#           </a>
#           ,
#           <a href="/wiki/Mogador,_Surrey" title="Mogador, Surrey">
#            Mogador
#           </a>
#           ,
#           <a href="/wiki/Box_Hill,_Surrey" title="Box Hill, Surrey">
#            Box Hill
#           </a>
#          </td>
#          <td>
#           Reigate and Banstead, Mole Valley
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT21
#          </th>
#          <td>
#           ASHTEAD
#          </td>
#          <td>
#           <a href="/wiki/Ashtead" title="Ashtead">
#            Ashtead
#           </a>
#          </td>
#          <td>
#           Mole Valley
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT22
#          </th>
#          <td>
#           LEATHERHEAD
#          </td>
#          <td>
#           <a href="/wiki/Leatherhead" title="Leatherhead">
#            Leatherhead
#           </a>
#           ,
#           <a href="/wiki/Oxshott" title="Oxshott">
#            Oxshott
#           </a>
#           ,
#           <a href="/wiki/Fetcham" title="Fetcham">
#            Fetcham
#           </a>
#          </td>
#          <td>
#           Mole Valley, Elmbridge
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT23
#          </th>
#          <td>
#           LEATHERHEAD
#          </td>
#          <td>
#           <a href="/wiki/Great_Bookham" title="Great Bookham">
#            Great Bookham
#           </a>
#           ,
#           <a href="/wiki/Little_Bookham" title="Little Bookham">
#            Little Bookham
#           </a>
#          </td>
#          <td>
#           Mole Valley, Guildford
#          </td>
#         </tr>
#         <tr>
#          <th>
#           KT24
#          </th>
#          <td>
#           LEATHERHEAD
#          </td>
#          <td>
#           <a href="/wiki/West_Horsley" title="West Horsley">
#            West Horsley
#           </a>
#           ,
#           <a href="/wiki/East_Horsley" title="East Horsley">
#            East Horsley
#           </a>
#           ,
#           <a href="/wiki/Effingham,_Surrey" title="Effingham, Surrey">
#            Effingham
#           </a>
#          </td>
#          <td>
#           Guildford, Mole Valley
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <h2>
#        <span class="mw-headline" id="Map">
#         Map
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=KT_postcode_area&amp;action=edit&amp;section=2" title="Edit section: Map">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <table class="metadata mbox-small" style="border:1px solid #aaa;background-color:#f9f9f9;font-size: 88%; line-height: 1.5em">
#        <tbody>
#         <tr>
#          <td style="width:1px">
#          </td>
#          <td class="mbox-text plainlist">
#           <span class="plainlinks">
#            <b>
#             <a class="external text" href="https://en.wikipedia.org/w/index.php?title=Template:Attached_KML/KT_postcode_area&amp;action=raw">
#              KML file
#             </a>
#            </b>
#            (
#            <a class="external text" href="https://en.wikipedia.org/w/index.php?title=Template:Attached_KML/KT_postcode_area&amp;action=edit">
#             edit
#            </a>
#            •
#            <a href="/wiki/Help:Attached_KML" title="Help:Attached KML">
#             help
#            </a>
#            )
#           </span>
#           <ul>
#            <li class="mw-empty-elt">
#            </li>
#           </ul>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <div class="kmldata" data-server="en.wikipedia.org" style="display:none;" title="Template:Attached KML/KT postcode area">
#        <a href="/wiki/Template:Attached_KML/KT_postcode_area" title="Template:Attached KML/KT postcode area">
#         Template:Attached KML/KT postcode area
#        </a>
#       </div>
#       <div style="display:none;" title="KML &amp; Wikidata">
#        KML is from Wikidata
#       </div>
#       <div class="thumb tnone">
#        <div class="thumbinner" style="width:702px;">
#         <div class="noresize">
#          <a href="/wiki/File:KT_postcode_area_map.svg" title="KT postcode area map">
#           <img alt="KT postcode area map, showing postcode districts, post towns and neighbouring postcode areas." class="thumbimage" data-file-height="800" data-file-width="1000" decoding="async" height="560" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d1/KT_postcode_area_map.svg/700px-KT_postcode_area_map.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d1/KT_postcode_area_map.svg/1050px-KT_postcode_area_map.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d1/KT_postcode_area_map.svg/1400px-KT_postcode_area_map.svg.png 2x" usemap="#ImageMap_ae2523dad59f0703" width="700"/>
#          </a>
#          <map name="ImageMap_ae2523dad59f0703">
#           <area alt="CR postcode area" coords="700,413,675,423,642,429,638,404,672,392,663,359,697,327,700,291,700,291" href="/wiki/CR_postcode_area" shape="poly" title="CR postcode area"/>
#           <area alt="CR postcode area" coords="700,162,689,147,666,117,691,79,700,79" href="/wiki/CR_postcode_area" shape="poly" title="CR postcode area"/>
#           <area alt="GU postcode area" coords="117,238,146,259,164,273,160,287,205,293,250,301,279,386,232,404,227,430,239,501,244,526,294,529,282,560,0,560,0,178,18,176,31,93,111,82,123,126,110,156,46,156,28,183" href="/wiki/GU_postcode_area" shape="poly" title="GU postcode area"/>
#           <area alt="RH postcode area" coords="675,423,700,413,700,560,282,560,294,529,329,479,365,473,419,454,439,420,507,433,520,449,465,493,499,498,553,467,589,481,658,460,642,429" href="/wiki/RH_postcode_area" shape="poly" title="RH postcode area"/>
#           <area alt="SL postcode area" coords="88,0,89,14,44,11,37,47,27,60,31,93,18,176,0,178,0,0" href="/wiki/SL_postcode_area" shape="poly" title="SL postcode area"/>
#           <area alt="SM postcode area" coords="603,277,597,235,593,203,614,169,611,171,593,146,597,140,635,116,666,117,689,147,700,162,700,291,700,291,697,327,663,359,615,328,608,328,600,322" href="/wiki/SM_postcode_area" shape="poly" title="SM postcode area"/>
#           <area alt="SW postcode area" coords="700,79,691,79,666,117,635,116,597,140,587,117,561,91,557,66,530,33,561,15,546,0,700,0" href="/wiki/SW_postcode_area" shape="poly" title="SW postcode area"/>
#           <area alt="TW postcode area" coords="546,0,561,15,530,33,516,64,499,54,470,55,481,82,453,96,420,95,404,99,360,106,355,108,343,111,310,140,295,156,235,163,218,139,211,132,199,92,174,96,123,126,111,82,31,93,27,60,37,47,44,11,89,14,88,0" href="/wiki/TW_postcode_area" shape="poly" title="TW postcode area"/>
#          </map>
#         </div>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:KT_postcode_area_map.svg" title="Enlarge">
#           </a>
#          </div>
#          KT postcode area map, showing postcode districts in red and post towns in grey text, with links to nearby
#          <a href="/wiki/CR_postcode_area" title="CR postcode area">
#           CR
#          </a>
#          ,
#          <a href="/wiki/GU_postcode_area" title="GU postcode area">
#           GU
#          </a>
#          ,
#          <a href="/wiki/RH_postcode_area" title="RH postcode area">
#           RH
#          </a>
#          ,
#          <a href="/wiki/SL_postcode_area" title="SL postcode area">
#           SL
#          </a>
#          ,
#          <a href="/wiki/SM_postcode_area" title="SM postcode area">
#           SM
#          </a>
#          ,
#          <a href="/wiki/SW_postcode_area" title="SW postcode area">
#           SW
#          </a>
#          and
#          <a href="/wiki/TW_postcode_area" title="TW postcode area">
#           TW
#          </a>
#          postcode areas.
#         </div>
#        </div>
#       </div>
#       <h2>
#        <span class="mw-headline" id="See_also">
#         See also
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=KT_postcode_area&amp;action=edit&amp;section=3" title="Edit section: See also">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <ul>
#        <li>
#         <a href="/wiki/Postcode_Address_File" title="Postcode Address File">
#          Postcode Address File
#         </a>
#        </li>
#        <li>
#         <a href="/wiki/List_of_postcode_areas_in_the_United_Kingdom" title="List of postcode areas in the United Kingdom">
#          List of postcode areas in the United Kingdom
#         </a>
#        </li>
#       </ul>
#       <h2>
#        <span class="mw-headline" id="References">
#         References
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=KT_postcode_area&amp;action=edit&amp;section=4" title="Edit section: References">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <div class="reflist" style="list-style-type: decimal;">
#        <div class="mw-references-wrap">
#         <ol class="references">
#          <li id="cite_note-1">
#           <span class="mw-cite-backlink">
#            <b>
#             <a href="#cite_ref-1">
#              ^
#             </a>
#            </b>
#           </span>
#           <span class="reference-text">
#            <style data-mw-deduplicate="TemplateStyles:r999302996">
#             .mw-parser-output cite.citation{font-style:inherit}.mw-parser-output .citation q{quotes:"\"""\"""'""'"}.mw-parser-output .id-lock-free a,.mw-parser-output .citation .cs1-lock-free a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/6/65/Lock-green.svg")right 0.1em center/9px no-repeat}.mw-parser-output .id-lock-limited a,.mw-parser-output .id-lock-registration a,.mw-parser-output .citation .cs1-lock-limited a,.mw-parser-output .citation .cs1-lock-registration a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/d/d6/Lock-gray-alt-2.svg")right 0.1em center/9px no-repeat}.mw-parser-output .id-lock-subscription a,.mw-parser-output .citation .cs1-lock-subscription a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/a/aa/Lock-red-alt-2.svg")right 0.1em center/9px no-repeat}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration{color:#555}.mw-parser-output .cs1-subscription span,.mw-parser-output .cs1-registration span{border-bottom:1px dotted;cursor:help}.mw-parser-output .cs1-ws-icon a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/4/4c/Wikisource-logo.svg")right 0.1em center/12px no-repeat}.mw-parser-output code.cs1-code{color:inherit;background:inherit;border:none;padding:inherit}.mw-parser-output .cs1-hidden-error{display:none;font-size:100%}.mw-parser-output .cs1-visible-error{font-size:100%}.mw-parser-output .cs1-maint{display:none;color:#33aa33;margin-left:0.3em}.mw-parser-output .cs1-format{font-size:95%}.mw-parser-output .cs1-kern-left,.mw-parser-output .cs1-kern-wl-left{padding-left:0.2em}.mw-parser-output .cs1-kern-right,.mw-parser-output .cs1-kern-wl-right{padding-right:0.2em}.mw-parser-output .citation .mw-selflink{font-weight:inherit}
#            </style>
#            <cite class="citation web cs1">
#             <a class="external text" href="http://www.ons.gov.uk/ons/guide-method/geography/products/postcode-directories/-nspp-/onspd-user-guide-and-version-notes.zip" rel="nofollow">
#              "ONS Postcode Directory Version Notes"
#             </a>
#             <span class="cs1-format">
#              (ZIP)
#             </span>
#             .
#             <i>
#              National Statistics Postcode Products
#             </i>
#             .
#             <a href="/wiki/Office_for_National_Statistics" title="Office for National Statistics">
#              Office for National Statistics
#             </a>
#             . May 2020. Table 2
#             <span class="reference-accessdate">
#              . Retrieved
#              <span class="nowrap">
#               19 June
#              </span>
#              2020
#             </span>
#             .
#            </cite>
#            <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=National+Statistics+Postcode+Products&amp;rft.atitle=ONS+Postcode+Directory+Version+Notes&amp;rft.pages=Table+2&amp;rft.date=2020-05&amp;rft_id=http%3A%2F%2Fwww.ons.gov.uk%2Fons%2Fguide-method%2Fgeography%2Fproducts%2Fpostcode-directories%2F-nspp-%2Fonspd-user-guide-and-version-notes.zip&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AKT+postcode+area">
#            </span>
#            Coordinates from mean of unit postcode points,
#            <link href="mw-data:TemplateStyles:r999302996" rel="mw-deduplicated-inline-style"/>
# ...
#         <li id="ca-talk">
#          <a accesskey="t" href="/wiki/Talk:KT_postcode_area" rel="discussion" title="Discuss improvements to the content page [t]">
#           Talk
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#      <nav aria-labelledby="p-variants-label" class="mw-portlet mw-portlet-variants emptyPortlet vector-menu vector-menu-dropdown" id="p-variants" role="navigation">
#       <input aria-labelledby="p-variants-label" class="vector-menu-checkbox" type="checkbox"/>
#       <h3 class="vector-menu-heading" id="p-variants-label">
#        <span>
#         Variants
#        </span>
#       </h3>
#       <div class="vector-menu-content">
#        <ul class="vector-menu-content-list">
#        </ul>
#       </div>
#      </nav>
#     </div>
#     <div id="right-navigation">
#      <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#      <nav aria-labelledby="p-views-label" class="mw-portlet mw-portlet-views vector-menu vector-menu-tabs" id="p-views" role="navigation">
#       <h3 class="vector-menu-heading" id="p-views-label">
#        <span>
#         Views
#        </span>
#       </h3>
#       <div class="vector-menu-content">
#        <ul class="vector-menu-content-list">
#         <li class="selected" id="ca-view">
#          <a href="/wiki/KT_postcode_area">
#           Read
#          </a>
#         </li>
#         <li id="ca-edit">
#          <a accesskey="e" href="/w/index.php?title=KT_postcode_area&amp;action=edit" title="Edit this page [e]">
#           Edit
#          </a>
#         </li>
#         <li id="ca-history">
#          <a accesskey="h" href="/w/index.php?title=KT_postcode_area&amp;action=history" title="Past revisions of this page [h]">
#           View history
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#      <nav aria-labelledby="p-cactions-label" class="mw-portlet mw-portlet-cactions emptyPortlet vector-menu vector-menu-dropdown" id="p-cactions" role="navigation">
#       <input aria-labelledby="p-cactions-label" class="vector-menu-checkbox" type="checkbox"/>
#       <h3 class="vector-menu-heading" id="p-cactions-label">
#        <span>
#         More
#        </span>
#       </h3>
#       <div class="vector-menu-content">
#        <ul class="vector-menu-content-list">
#        </ul>
#       </div>
#      </nav>
#      <div id="p-search" role="search">
#       <h3>
#        <label for="searchInput">
#         Search
#        </label>
#       </h3>
#       <form action="/w/index.php" id="searchform">
#        <div data-search-loc="header-navigation" id="simpleSearch">
#         <input accesskey="f" autocapitalize="sentences" id="searchInput" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" type="search"/>
#         <input name="title" type="hidden" value="Special:Search"/>
#         <input class="searchButton mw-fallbackSearchButton" id="mw-searchButton" name="fulltext" title="Search Wikipedia for this text" type="submit" value="Search"/>
#         <input class="searchButton" id="searchButton" name="go" title="Go to a page with this exact name if it exists" type="submit" value="Go"/>
#        </div>
#       </form>
#      </div>
#     </div>
#    </div>
#    <div id="mw-panel">
#     <div id="p-logo" role="banner">
#      <a class="mw-wiki-logo" href="/wiki/Main_Page" title="Visit the main page">
#      </a>
#     </div>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-navigation-label" class="mw-portlet mw-portlet-navigation vector-menu vector-menu-portal portal" id="p-navigation" role="navigation">
#      <h3 class="vector-menu-heading" id="p-navigation-label">
#       <span>
#        Navigation
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li id="n-mainpage-description">
#         <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]">
#          Main page
#         </a>
#        </li>
#        <li id="n-contents">
#         <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia">
#          Contents
#         </a>
#        </li>
#        <li id="n-currentevents">
#         <a href="/wiki/Portal:Current_events" title="Articles related to current events">
#          Current events
#         </a>
#        </li>
#        <li id="n-randompage">
#         <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]">
#          Random article
#         </a>
#        </li>
#        <li id="n-aboutsite">
#         <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works">
#          About Wikipedia
#         </a>
#        </li>
#        <li id="n-contactpage">
#         <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">
#          Contact us
#         </a>
#        </li>
#        <li id="n-sitesupport">
#         <a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation">
#          Donate
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-interaction-label" class="mw-portlet mw-portlet-interaction vector-menu vector-menu-portal portal" id="p-interaction" role="navigation">
#      <h3 class="vector-menu-heading" id="p-interaction-label">
#       <span>
#        Contribute
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li id="n-help">
#         <a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">
#          Help
#         </a>
#        </li>
#        <li id="n-introduction">
#         <a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia">
#          Learn to edit
#         </a>
#        </li>
#        <li id="n-portal">
#         <a href="/wiki/Wikipedia:Community_portal" title="The hub for editors">
#          Community portal
#         </a>
#        </li>
#        <li id="n-recentchanges">
#         <a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]">
#          Recent changes
#         </a>
#        </li>
#        <li id="n-upload">
#         <a href="/wiki/Wikipedia:File_Upload_Wizard" title="Add images or other media for use on Wikipedia">
#          Upload file
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-tb-label" class="mw-portlet mw-portlet-tb vector-menu vector-menu-portal portal" id="p-tb" role="navigation">
#      <h3 class="vector-menu-heading" id="p-tb-label">
#       <span>
#        Tools
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li id="t-whatlinkshere">
#         <a accesskey="j" href="/wiki/Special:WhatLinksHere/KT_postcode_area" title="List of all English Wikipedia pages containing links to this page [j]">
#          What links here
#         </a>
#        </li>
#        <li id="t-recentchangeslinked">
#         <a accesskey="k" href="/wiki/Special:RecentChangesLinked/KT_postcode_area" rel="nofollow" title="Recent changes in pages linked from this page [k]">
#          Related changes
#         </a>
#        </li>
#        <li id="t-upload">
#         <a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]">
#          Upload file
#         </a>
#        </li>
#        <li id="t-specialpages">
#         <a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">
#          Special pages
#         </a>
#        </li>
#        <li id="t-permalink">
#         <a href="/w/index.php?title=KT_postcode_area&amp;oldid=983530632" title="Permanent link to this revision of this page">
#          Permanent link
#         </a>
#        </li>
#        <li id="t-info">
#         <a href="/w/index.php?title=KT_postcode_area&amp;action=info" title="More information about this page">
#          Page information
#         </a>
#        </li>
#        <li id="t-cite">
#         <a href="/w/index.php?title=Special:CiteThisPage&amp;page=KT_postcode_area&amp;id=983530632&amp;wpFormIdentifier=titleform" title="Information on how to cite this page">
#          Cite this page
#         </a>
#        </li>
#        <li id="t-wikibase">
#         <a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q6339413" title="Structured data on this page hosted by Wikidata [g]">
#          Wikidata item
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-coll-print_export-label" class="mw-portlet mw-portlet-coll-print_export vector-menu vector-menu-portal portal" id="p-coll-print_export" role="navigation">
#      <h3 class="vector-menu-heading" id="p-coll-print_export-label">
#       <span>
#        Print/export
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li id="coll-download-as-rl">
#         <a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=KT_postcode_area&amp;action=show-download-screen" title="Download this page as a PDF file">
#          Download as PDF
#         </a>
#        </li>
#        <li id="t-print">
#         <a accesskey="p" href="/w/index.php?title=KT_postcode_area&amp;printable=yes" title="Printable version of this page [p]">
#          Printable version
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-lang-label" class="mw-portlet mw-portlet-lang vector-menu vector-menu-portal portal" id="p-lang" role="navigation">
#      <h3 class="vector-menu-heading" id="p-lang-label">
#       <span>
#        Languages
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#       </ul>
#       <div class="after-portlet after-portlet-lang">
#        <span class="uls-after-portlet-link">
#        </span>
#        <span class="wb-langlinks-add wb-langlinks-link">
#         <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q6339413#sitelinks-wikipedia" title="Add interlanguage links">
#          Add links
#         </a>
#        </span>
#       </div>
#      </div>
#     </nav>
#    </div>
#   </div>
#   <footer class="mw-footer" id="footer" role="contentinfo">
#    <ul id="footer-info">
#     <li id="footer-info-lastmod">
#      This page was last edited on 14 October 2020, at 19:18
#      <span class="anonymous-show">
#       (UTC)
#      </span>
#      .
#     </li>
#     <li id="footer-info-copyright">
#      Text is available under the
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">
#       Creative Commons Attribution-ShareAlike License
#      </a>
#      <a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;">
#      </a>
#      ;
# additional terms may apply.  By using this site, you agree to the
#      <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">
#       Terms of Use
#      </a>
#      and
#      <a href="//foundation.wikimedia.org/wiki/Privacy_policy">
#       Privacy Policy
#      </a>
#      . Wikipedia® is a registered trademark of the
#      <a href="//www.wikimediafoundation.org/">
#       Wikimedia Foundation, Inc.
#      </a>
#      , a non-profit organization.
#     </li>
#    </ul>
#    <ul id="footer-places">
#     <li id="footer-places-privacy">
#      <a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">
#       Privacy policy
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:About" title="Wikipedia:About">
#       About Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimer">
#      <a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">
#       Disclaimers
#      </a>
#     </li>
#     <li id="footer-places-contact">
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#       Contact Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=KT_postcode_area&amp;mobileaction=toggle_view_mobile">
#       Mobile view
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#       Developers
#      </a>
#     </li>
#     <li id="footer-places-statslink">
#      <a href="https://stats.wikimedia.org/#/en.wikipedia.org">
#       Statistics
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://foundation.wikimedia.org/wiki/Cookie_statement">
#       Cookie statement
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="https://www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#    <div style="clear: both;">
#    </div>
#   </footer>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.740","walltime":"1.226","ppvisitednodes":{"value":3990,"limit":1000000},"postexpandincludesize":{"value":58885,"limit":2097152},"templateargumentsize":{"value":7518,"limit":2097152},"expansiondepth":{"value":18,"limit":40},"expensivefunctioncount":{"value":4,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":12848,"limit":5000000},"entityaccesscount":{"value":2,"limit":400},"timingprofile":["100.00% 1124.402      1 -total"," 58.64%  659.394      1 Template:Infobox_UK_postcode_area"," 51.42%  578.142      1 Template:Infobox_settlement"," 43.88%  493.413      1 Template:Infobox"," 12.45%  140.015      1 Template:Short_description"," 11.09%  124.700      2 Template:Cite_web","  6.89%   77.475      1 Template:Postcode_areas_in_the_United_Kingdom","  6.84%   76.953      8 Template:Main_other","  6.55%   73.668      2 Template:Pagetype","  6.29%   70.717      2 Template:Attached_KML"]},"scribunto":{"limitreport-timeusage":{"value":"0.365","limit":"10.000"},"limitreport-memusage":{"value":5086976,"limit":52428800}},"cachereport":{"origin":"mw1322","timestamp":"20210212164452","ttl":2592000,"transientcontent":false}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"KT postcode area","url":"https:\/\/en.wikipedia.org\/wiki\/KT_postcode_area","sameAs":"http:\/\/www.wikidata.org\/entity\/Q6339413","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q6339413","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2005-01-26T21:02:29Z","dateModified":"2020-10-14T19:18:22Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/d\/d9\/United_Kingdom_adm_location_map.svg","headline":"postcode area within the United Kingdom"}
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":194,"wgHostname":"mw1326"});});
#   </script>
#  </body>
# </html>

# %%
My_table = soup.find("table", {"class":"wikitable sortable"})
My_table
# Out:
# <table class="wikitable sortable" style="font-size:95%">
# <tbody><tr style="white-space:nowrap">
# <th>Postcode district
# </th>
# <th><a href="/wiki/Post_town" title="Post town">Post town</a>
# </th>
# <th>Coverage
# </th>
# <th>Local authority area(s)
# </th></tr>
# <tr>
# <th>KT1
# </th>
# <td>KINGSTON UPON THAMES
# </td>
# <td><a href="/wiki/Kingston_upon_Thames" title="Kingston upon Thames">Kingston upon Thames</a>, <a href="/wiki/Hampton_Wick" title="Hampton Wick">Hampton Wick</a>, part of <a href="/wiki/Norbiton" title="Norbiton">Norbiton</a>
# </td>
# <td><a href="/wiki/Royal_Borough_of_Kingston_upon_Thames" title="Royal Borough of Kingston upon Thames">Kingston upon Thames</a>, <a href="/wiki/London_Borough_of_Richmond_upon_Thames" title="London Borough of Richmond upon Thames">Richmond upon Thames</a>
# </td></tr>
# <tr>
# <th>KT2
# </th>
# <td>KINGSTON UPON THAMES
# </td>
# <td>Kingston upon Thames, <a href="/wiki/Canbury" title="Canbury">Canbury</a>, <a href="/wiki/Coombe,_Kingston_upon_Thames" title="Coombe, Kingston upon Thames">Coombe</a>, part of <a href="/wiki/Norbiton" title="Norbiton">Norbiton</a>
# </td>
# <td>Kingston upon Thames, Richmond upon Thames
# </td></tr>
# <tr>
# <th>KT3
# </th>
# <td>NEW MALDEN
# </td>
# <td><a href="/wiki/Motspur_Park" title="Motspur Park">Motspur Park</a>, <a href="/wiki/New_Malden" title="New Malden">New Malden</a>, part of <a href="/wiki/Old_Malden" title="Old Malden">Old Malden</a>
# </td>
# <td>Kingston upon Thames, <a href="/wiki/London_Borough_of_Merton" title="London Borough of Merton">Merton</a>
# </td></tr>
# <tr>
# <th>KT4
# </th>
# <td>WORCESTER PARK
# </td>
# <td><a href="/wiki/Worcester_Park" title="Worcester Park">Worcester Park</a>, <a href="/wiki/Cuddington,_Surrey" title="Cuddington, Surrey">Cuddington</a>, part of <a href="/wiki/Old_Malden" title="Old Malden">Old Malden</a>, <a href="/wiki/Stoneleigh,_Surrey" title="Stoneleigh, Surrey">Stoneleigh</a>
# </td>
# <td><a href="/wiki/London_Borough_of_Sutton" title="London Borough of Sutton">Sutton</a>, <a href="/wiki/Epsom_and_Ewell" title="Epsom and Ewell">Epsom and Ewell</a>, Kingston upon Thames, Merton
# </td></tr>
# <tr>
# <th>KT5
# </th>
# <td>SURBITON
# </td>
# <td><a href="/wiki/Berrylands" title="Berrylands">Berrylands</a>, part of <a href="/wiki/Surbiton" title="Surbiton">Surbiton</a>, part of <a href="/wiki/Tolworth" title="Tolworth">Tolworth</a>
# </td>
# <td>Kingston upon Thames
# </td></tr>
# <tr>
# <th>KT6
# </th>
# <td>SURBITON
# </td>
# <td><a href="/wiki/Surbiton" title="Surbiton">Surbiton</a>, <a href="/wiki/Tolworth" title="Tolworth">Tolworth</a>, part of <a href="/wiki/Long_Ditton" title="Long Ditton">Long Ditton</a>, <a href="/wiki/Seething_Wells" title="Seething Wells">Seething Wells</a>
# </td>
# <td><a href="/wiki/Kingston_upon_Thames" title="Kingston upon Thames">Kingston upon Thames</a>, <a href="/wiki/Borough_of_Elmbridge" title="Borough of Elmbridge">Elmbridge</a>
# </td></tr>
# <tr>
# <th>KT7
# </th>
# <td>THAMES DITTON
# </td>
# <td>part of <a href="/wiki/Long_Ditton" title="Long Ditton">Long Ditton</a>, <a href="/wiki/Thames_Ditton" title="Thames Ditton">Thames Ditton</a>, part of <a href="/wiki/Weston_Green" title="Weston Green">Weston Green</a>
# </td>
# <td><a href="/wiki/Kingston_upon_Thames" title="Kingston upon Thames">Kingston upon Thames</a>, <a href="/wiki/Borough_of_Elmbridge" title="Borough of Elmbridge">Elmbridge</a>
# </td></tr>
# <tr>
# <th>KT8
# </th>
# <td>EAST MOLESEY; WEST MOLESEY
# </td>
# <td><a class="mw-redirect" href="/wiki/East_Molesey" title="East Molesey">East Molesey</a>, <a class="mw-redirect" href="/wiki/West_Molesey" title="West Molesey">West Molesey</a>, <a href="/wiki/Hampton_Court_Palace" title="Hampton Court Palace">Hampton Court Palace and part of its Park</a>; 1.5 Thames islands, part of <a href="/wiki/Bushy_Park" title="Bushy Park">Bushy Park</a>, Hampton Court neighbourhood, <a href="/wiki/Hampton,_London" title="Hampton, London">Hampton</a>
# </td>
# <td>Elmbridge, Richmond upon Thames
# </td></tr>
# <tr>
# <th>KT9
# </th>
# <td>CHESSINGTON
# </td>
# <td><a href="/wiki/Chessington" title="Chessington">Chessington</a> including <a href="/wiki/Malden_Rushett" title="Malden Rushett">Malden Rushett</a>, <a href="/wiki/Hook,_London" title="Hook, London">Hook</a>, part of Long Ditton
# </td>
# <td>Kingston upon Thames; Elmbridge
# </td></tr>
# <tr>
# <th>KT10
# </th>
# <td>ESHER
# </td>
# <td><a href="/wiki/Esher" title="Esher">Esher</a>, <a href="/wiki/Claygate" title="Claygate">Claygate</a>, <a href="/wiki/Hinchley_Wood" title="Hinchley Wood">Hinchley Wood</a>, part of <a href="/wiki/Weston_Green" title="Weston Green">Weston Green</a>
# </td>
# <td><a href="/wiki/Borough_of_Elmbridge" title="Borough of Elmbridge">Elmbridge</a>
# </td></tr>
# <tr>
# <th>KT11
# </th>
# <td>COBHAM
# </td>
# <td><a href="/wiki/Cobham,_Surrey" title="Cobham, Surrey">Cobham</a>, <a href="/wiki/Stoke_d%27Abernon" title="Stoke d'Abernon">Stoke d'Abernon</a>, <a href="/wiki/Downside,_Surrey" title="Downside, Surrey">Downside</a>, <a href="/wiki/Hatchford" title="Hatchford">Hatchford</a>, parts of <a href="/wiki/Wisley" title="Wisley">Wisley</a>, <a href="/wiki/Ockham,_Surrey" title="Ockham, Surrey">Ockham</a> and <a href="/wiki/Hersham" title="Hersham">Hersham</a>
# </td>
# <td>Elmbridge, <a href="/wiki/Borough_of_Guildford" title="Borough of Guildford">Guildford</a>, <a href="/wiki/Mole_Valley" title="Mole Valley">Mole Valley</a>
# </td></tr>
# <tr>
# <th>KT12
# </th>
# <td>WALTON-ON-THAMES
# </td>
# <td><a href="/wiki/Walton-on-Thames" title="Walton-on-Thames">Walton-on-Thames</a>, <a href="/wiki/Hersham" title="Hersham">Hersham</a>, <a href="/wiki/Whiteley_Village" title="Whiteley Village">Whiteley Village</a>
# </td>
# <td>Elmbridge
# </td></tr>
# <tr>
# <th>KT13
# </th>
# <td>WEYBRIDGE
# </td>
# <td><a href="/wiki/Weybridge" title="Weybridge">Weybridge</a>, <a href="/wiki/Oatlands,_Surrey" title="Oatlands, Surrey">Oatlands</a>, <a class="mw-redirect" href="/wiki/Saint_George%27s_Hill" title="Saint George's Hill">Saint George's Hill</a>, <a href="/wiki/Addlestone#Hamm_Court" title="Addlestone">Hamm Court</a>
# </td>
# <td>Elmbridge, <a href="/wiki/Borough_of_Runnymede" title="Borough of Runnymede">Runnymede</a>
# </td></tr>
# <tr>
# <th>KT14
# </th>
# <td>WEST BYFLEET
# </td>
# <td><a href="/wiki/Byfleet" title="Byfleet">Byfleet</a>, <a href="/wiki/West_Byfleet" title="West Byfleet">West Byfleet</a>
# </td>
# <td><a href="/wiki/Borough_of_Woking" title="Borough of Woking">Woking</a>, Elmbridge, Runnymede
# </td></tr>
# <tr>
# <th>KT15
# </th>
# <td>ADDLESTONE
# </td>
# <td><a href="/wiki/Addlestone" title="Addlestone">Addlestone</a>, <a href="/wiki/New_Haw" title="New Haw">New Haw</a>, <a href="/wiki/Woodham,_Surrey" title="Woodham, Surrey">Woodham</a>
# </td>
# <td>Runnymede, Woking
# </td></tr>
# <tr>
# <th>KT16
# </th>
# <td>CHERTSEY
# </td>
# <td><a href="/wiki/Chertsey" title="Chertsey">Chertsey</a>, <a href="/wiki/Ottershaw" title="Ottershaw">Ottershaw</a>, <a href="/wiki/Longcross" title="Longcross">Longcross</a>, <a href="/wiki/Lyne,_Surrey" title="Lyne, Surrey">Lyne</a>, <a href="/wiki/Dumsey_Meadow" title="Dumsey Meadow">Dumsey Meadow</a> in <a href="/wiki/Littleton,_Spelthorne" title="Littleton, Spelthorne">Littleton</a>
# </td>
# <td>Runnymede, <a href="/wiki/Borough_of_Spelthorne" title="Borough of Spelthorne">Spelthorne</a>
# </td></tr>
# <tr>
# <th>KT17
# </th>
# <td>EPSOM
# </td>
# <td><a href="/wiki/Epsom" title="Epsom">Epsom</a>, <a href="/wiki/Ewell" title="Ewell">Ewell</a>, <a href="/wiki/Stoneleigh,_Surrey" title="Stoneleigh, Surrey">Stoneleigh</a>
# </td>
# <td>Epsom and Ewell, <a href="/wiki/Reigate_and_Banstead" title="Reigate and Banstead">Reigate and Banstead</a>, Sutton
# </td></tr>
# <tr>
# <th>KT18
# </th>
# <td>EPSOM
# </td>
# <td><a href="/wiki/Epsom" title="Epsom">Epsom</a>, <a href="/wiki/Tattenham_Corner" title="Tattenham Corner">Tattenham Corner</a>, <a href="/wiki/Headley,_Surrey" title="Headley, Surrey">Headley</a>, <a href="/wiki/Langley_Vale" title="Langley Vale">Langley Vale</a>
# </td>
# <td>Epsom and Ewell, Mole Valley, Reigate and Banstead
# </td></tr>
# <tr>
# <th>KT19
# </th>
# <td>EPSOM
# </td>
# <td><a href="/wiki/Epsom" title="Epsom">Epsom</a>, West Ewell, <a href="/wiki/Stoneleigh,_Surrey" title="Stoneleigh, Surrey">Stoneleigh</a>, <a class="mw-redirect" href="/wiki/Horton,_Surrey" title="Horton, Surrey">Horton</a>, Longmead
# </td>
# <td>Epsom and Ewell
# </td></tr>
# <tr>
# <th>KT20
# </th>
# <td>TADWORTH
# </td>
# <td><a href="/wiki/Tadworth" title="Tadworth">Tadworth</a>, <a href="/wiki/Kingswood,_Surrey" title="Kingswood, Surrey">Kingswood</a>, <a href="/wiki/Lower_Kingswood" title="Lower Kingswood">Lower Kingswood</a>, <a href="/wiki/Walton-on-the-Hill" title="Walton-on-the-Hill">Walton-on-the-Hill</a>, <a href="/wiki/Burgh_Heath" title="Burgh Heath">Burgh Heath</a>, <a href="/wiki/Mogador,_Surrey" title="Mogador, Surrey">Mogador</a>, <a href="/wiki/Box_Hill,_Surrey" title="Box Hill, Surrey">Box Hill</a>
# </td>
# <td>Reigate and Banstead, Mole Valley
# </td></tr>
# <tr>
# <th>KT21
# </th>
# <td>ASHTEAD
# </td>
# <td><a href="/wiki/Ashtead" title="Ashtead">Ashtead</a>
# </td>
# <td>Mole Valley
# </td></tr>
# <tr>
# <th>KT22
# </th>
# <td>LEATHERHEAD
# </td>
# <td><a href="/wiki/Leatherhead" title="Leatherhead">Leatherhead</a>, <a href="/wiki/Oxshott" title="Oxshott">Oxshott</a>, <a href="/wiki/Fetcham" title="Fetcham">Fetcham</a>
# </td>
# <td>Mole Valley, Elmbridge
# </td></tr>
# <tr>
# <th>KT23
# </th>
# <td>LEATHERHEAD
# </td>
# <td><a href="/wiki/Great_Bookham" title="Great Bookham">Great Bookham</a>, <a href="/wiki/Little_Bookham" title="Little Bookham">Little Bookham</a>
# </td>
# <td>Mole Valley, Guildford
# </td></tr>
# <tr>
# <th>KT24
# </th>
# <td>LEATHERHEAD
# </td>
# <td><a href="/wiki/West_Horsley" title="West Horsley">West Horsley</a>, <a href="/wiki/East_Horsley" title="East Horsley">East Horsley</a>, <a href="/wiki/Effingham,_Surrey" title="Effingham, Surrey">Effingham</a>
# </td>
# <td>Guildford, Mole Valley
# </td></tr></tbody></table>

# %%
df_KT = pd.read_html(str(My_table))[0]
df_KT.head()
# Out:
#   Postcode district             Post town  \
# 0               KT1  KINGSTON UPON THAMES
# 1               KT2  KINGSTON UPON THAMES
# 2               KT3            NEW MALDEN
# 3               KT4        WORCESTER PARK
# 4               KT5              SURBITON
#
#                                                      Coverage  \
# 0        Kingston upon Thames, Hampton Wick, part of Norbiton
# 1     Kingston upon Thames, Canbury, Coombe, part of Norbiton
# 2                Motspur Park, New Malden, part of Old Malden
# 3  Worcester Park, Cuddington, part of Old Malden, Stoneleigh
# 4              Berrylands, part of Surbiton, part of Tolworth
#
#                                  Local authority area(s)
# 0             Kingston upon Thames, Richmond upon Thames
# 1             Kingston upon Thames, Richmond upon Thames
# 2                           Kingston upon Thames, Merton
# 3  Sutton, Epsom and Ewell, Kingston upon Thames, Merton
# 4                                   Kingston upon Thames

# %%
# initialize Nominatim API  
geolocator = Nominatim(user_agent="geoapiExercises") 


lat = 51.2707207
long = -0.4129309
tuple=(lat,long)

location = geolocator.reverse(tuple)
#print(location.address)
    
# traverse the data 
data = location.raw 
loc_data = data['address']
# print(data)

print("post code: ", loc_data["postcode"].split()[0], "City: ", loc_data["town"])
print(type(loc_data["postcode"].split()[0]))
# Out:
# post code:  KT24 City:  Guildford
# <class 'str'>

# %%
def get_postcode(lat,long, index):
    
    global city
    
    geolocator = Nominatim(user_agent="geoapiExercises") 
    tuple_coordinate = (lat,long)
    location = geolocator.reverse(tuple_coordinate)
    
    # traverse the data 
    data = location.raw 
    loc_data = data['address']
    
    try:
        postcode = loc_data["postcode"].split()[0]
        
    except KeyError as KE:
        print("index: ", index, "Key error: ", loc_data)
        postcode = np.nan
        
    try:
        if "city" in loc_data:
            city = loc_data["city"]
        elif "town" in loc_data:
            city = loc_data["town"]
        
    except:
        print("index: ", index, "City Error: ", loc_data)
        city = np.nan
        
    return postcode, city

# %%
#Notice that the trick is on the result_type parameter of apply, that will expand its result into a DataFrame 
#that can be directly assign to new/old columns.
df_subset[["Postcode", "City"]] = df_subset.apply(lambda row: get_postcode(row["latitude"], row["longitude"], index=row.name), axis=1, result_type="expand")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_subset
# Out:
#              id  bedrooms  bathrooms propertySubType   latitude  longitude  \
# 0      89386117         4        3.0        Terraced  51.338951  -0.262866
# 2      86007409         4        2.0        Detached  51.379100  -0.342057
# 3      73255458         2        2.0       Apartment  51.365766  -0.367829
# 4      88981993         4        2.0        Detached  51.355801  -0.300656
# 5      88344589         6        2.0        Detached  51.402050  -0.252850
# ...         ...       ...        ...             ...        ...        ...
# 1043  101151050         4        3.0           House  51.375669  -0.483489
# 1044   88759417         3        2.0   Semi-Detached  51.342006  -0.269210
# 1045   96145934         3        1.0        Terraced  51.398266  -0.234223
# 1047   99042143         3        2.0   Semi-Detached  51.364906  -0.268977
# 1048   87124249         3        1.0  End of Terrace  51.397150  -0.244270
#
#         Price                    Specials  Price/Bedroom Postcode  \
# 0      575000                  Video Tour       143750.0     KT17
# 2     1000000  Potential to extend (STPP)       250000.0     KT10
# 3     1000000             Premium Listing       500000.0     KT10
# 4     1000000            Close to Station       250000.0      KT9
# 5     1000000               Double Garage       166667.0      KT3
# ...       ...                         ...            ...      ...
# 1043   560000                                   140000.0     KT15
# 1044   560000                  Video Tour       186667.0     KT19
# 1045   560000            Close to Station       186667.0      KT3
# 1047   555000                Virtual Tour       185000.0     KT19
# 1048   550000                    No Chain       183333.0      KT3
#
#              (Postcode, City)             City
# 0     (KT17, Epsom and Ewell)  Epsom and Ewell
# 2           (KT10, Elmbridge)        Elmbridge
# 3               (KT10, Esher)            Esher
# 4               (KT9, London)           London
# 5               (KT3, London)           London
# ...                       ...              ...
# 1043       (KT15, Addlestone)       Addlestone
# 1044  (KT19, Epsom and Ewell)  Epsom and Ewell
# 1045            (KT3, London)           London
# 1047  (KT19, Epsom and Ewell)  Epsom and Ewell
# 1048            (KT3, London)           London
#
# [897 rows x 12 columns]

# %%
df_subset.loc[198:208]
# Out:
#             id  bedrooms  bathrooms propertySubType   latitude  longitude  \
# 198  102940379         5        4.0        Detached  51.361220  -0.314090
# 199   88981546         5        4.0        Detached  51.322767  -0.236435
# 201   84646966         5        2.0        Detached  51.364180  -0.505530
# 202   77780484         3        1.0           House  51.381984  -0.295067
# 203   78489558         3        1.0        Detached  51.409899  -0.297467
# 205   89481094         4        2.0        Detached  51.323169  -0.234848
# 206  100397348         4        4.0        Detached  51.356764  -0.313813
# 208  102437828         3        2.0        Detached  51.348620  -0.246270
#
#       Price         Specials  Price/Bedroom Postcode  \
# 198  850000      New Listing       170000.0      KT9
# 199  850000                        170000.0     KT17
# 201  849950                        169990.0     KT15
# 202  849950                        283317.0      KT6
# 203  849000                        283000.0      KT1
# 205  845000                        211250.0     KT17
# 206  845000  Premium Listing       211250.0      KT9
# 208  840000           Annexe       280000.0     KT17
#
#                  (Postcode, City)                  City
# 198                 (KT9, London)                London
# 199  (KT17, Reigate and Banstead)  Reigate and Banstead
# 201             (KT15, Runnymede)             Runnymede
# 202                 (KT6, London)                London
# 203                 (KT1, London)                London
# 205  (KT17, Reigate and Banstead)  Reigate and Banstead
# 206                 (KT9, London)                London
# 208       (KT17, Epsom and Ewell)       Epsom and Ewell

# %%
df_subset["City"].value_counts()
# Out:
# London                  412
# Elmbridge               170
# Epsom and Ewell          80
# Mole Valley              44
# Reigate and Banstead     37
# Runnymede                30
# Weybridge                22
# Woking                   17
# Chertsey                 15
# Molesey                  15
# Esher                    12
# Addlestone               12
# Leatherhead              11
# Guildford                 9
# Cobham                    6
# Banstead                  4
# Spelthorne                1
# Name: City, dtype: int64

# %%
df_subset["Greater London"] = df_subset.apply(lambda x: 'London' if df_subset["City"] == "London" else "Outside")
df_subset
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-64d763dfb985> in <module>
# ----> 1 df_subset["Greater London"] = df_subset.apply(lambda x: 'London1' if df_subset["City"] == "London" else "Outside")
#       2 df_subset
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-98-64d763dfb985> in <lambda>(x)
# ----> 1 df_subset["Greater London"] = df_subset.apply(lambda x: 'London1' if df_subset["City"] == "London" else "Outside")
#       2 df_subset
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df_subset["Postcode"].value_counts().sort_index()
# Out:
# KT1      50
# KT10     30
# KT11     27
# KT12     59
# KT13     61
# KT14     16
# KT15     29
# KT16     29
# KT17     31
# KT18     14
# KT19     37
# KT2      81
# KT20     27
# KT21     12
# KT22     30
# KT23     12
# KT24      9
# KT3     126
# KT4      43
# KT5      44
# KT6      71
# KT7      17
# KT8      30
# KT9      12
# Name: Postcode, dtype: int64

# %%
#Drop GU25 as its not part of KT list
# df_subset = df_subset[df_subset["Postcode"] != "GU25"]
# df_subset

# %%
df_subset = df_subset[df_subset["Postcode"].isin(df_KT["Postcode district"])]
df_subset["Postcode"].value_counts().sort_index()
# Out:
# KT1      50
# KT10     30
# KT11     27
# KT12     59
# KT13     61
# KT14     16
# KT15     29
# KT16     29
# KT17     31
# KT18     14
# KT19     37
# KT2      81
# KT20     27
# KT21     12
# KT22     30
# KT23     12
# KT24      9
# KT3     126
# KT4      43
# KT5      44
# KT6      71
# KT7      17
# KT8      30
# KT9      12
# Name: Postcode, dtype: int64

# %% [markdown]
# ### 3. Visualise Data

# %%
df = df_subset

# %% [markdown]
# **Drop data**
# Drop data where bathrooms = 0 as these are not considered livable
# Drop data where propertySubType = Not Specified

# %%
df.drop(df.loc[df["bathrooms"] == 0].index, inplace=True, axis=0)
df["bathrooms"].value_counts()
# Out:
# 2.0    500
# 1.0    262
# 3.0    124
# 4.0     10
# 5.0      1
# Name: bathrooms, dtype: int64

# %%
df.drop(df.loc[df["propertySubType"] == "Not Specified"].index, inplace=True, axis=0)
df["propertySubType"].value_counts()
# Out:
# Semi-Detached          304
# Detached               209
# Flat                    85
# Terraced                80
# Apartment               58
# End of Terrace          54
# House                   40
# Town House              23
# Maisonette              13
# Penthouse               11
# Link Detached House      4
# Cottage                  4
# Mews                     3
# Ground Flat              2
# Detached Villa           1
# Character Property       1
# Chalet                   1
# Villa                    1
# Barn Conversion          1
# Semi-detached Villa      1
# Duplex                   1
# Name: propertySubType, dtype: int64

# %%
fig, ax =plt.subplots(1,2, figsize=(12,5))
sns.countplot(df['bedrooms'], ax=ax[0])
sns.countplot(df['bathrooms'], ax=ax[1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bathrooms', ylabel='count'>

# %%
fig, ax =plt.subplots(1 ,figsize=(12,5))
sns.countplot(df['propertySubType'], ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='propertySubType', ylabel='count'>
# [Text(0, 0, 'Terraced'),
#  Text(1, 0, 'Detached'),
#  Text(2, 0, 'Apartment'),
#  Text(3, 0, 'Semi-Detached'),
#  Text(4, 0, 'Penthouse'),
#  Text(5, 0, 'Town House'),
#  Text(6, 0, 'Flat'),
#  Text(7, 0, 'Villa'),
#  Text(8, 0, 'End of Terrace'),
#  Text(9, 0, 'House'),
#  Text(10, 0, 'Detached Villa'),
#  Text(11, 0, 'Barn Conversion'),
#  Text(12, 0, 'Maisonette'),
#  Text(13, 0, 'Cottage'),
#  Text(14, 0, 'Link Detached House'),
#  Text(15, 0, 'Mews'),
#  Text(16, 0, 'Duplex'),
#  Text(17, 0, 'Character Property'),
#  Text(18, 0, 'Ground Flat'),
#  Text(19, 0, 'Semi-detached Villa'),
#  Text(20, 0, 'Chalet')]

# %%
df.dtypes
# Out:
# id                    int64
# bedrooms              int64
# bathrooms           float64
# propertySubType      object
# latitude            float64
# longitude           float64
# Price                 int64
# Specials             object
# Price/Bedroom       float64
# Postcode             object
# (Postcode, City)     object
# City                 object
# dtype: object

# %%
sns.jointplot(x='bedrooms', y='Price', data=df[['bedrooms','Price']])

# %%
sns.boxplot(x='bedrooms', y='Price', data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='Price'>

# %%
sns.boxplot(x='bedrooms', y='Price/Bedroom', data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='Price/Bedroom'>

# %%
x_order = ["KT1", "KT2", "KT3", "KT4", "KT5", "KT6", "KT7", "KT8", "KT9", "KT10", "KT11", "KT12", "KT13", "KT14", "KT15", "KT16", "TK17", "KT18", "KT19", "KT20", "KT21", "KT22", "KT23", "KT24"]

# %%
plt.figure(figsize=(15,10))
ax = sns.boxplot(x='Postcode', y='Price', data=df, order = x_order)
ax.set_xticklabels(ax.get_xticklabels(), rotation=50, ha="right")
ax.tick_params(labelsize=13)
# Out:
# [Text(0, 0, 'KT1'),
#  Text(1, 0, 'KT2'),
#  Text(2, 0, 'KT3'),
#  Text(3, 0, 'KT4'),
#  Text(4, 0, 'KT5'),
#  Text(5, 0, 'KT6'),
#  Text(6, 0, 'KT7'),
#  Text(7, 0, 'KT8'),
#  Text(8, 0, 'KT9'),
#  Text(9, 0, 'KT10'),
#  Text(10, 0, 'KT11'),
#  Text(11, 0, 'KT12'),
#  Text(12, 0, 'KT13'),
#  Text(13, 0, 'KT14'),
#  Text(14, 0, 'KT15'),
#  Text(15, 0, 'KT16'),
#  Text(16, 0, 'TK17'),
#  Text(17, 0, 'KT18'),
#  Text(18, 0, 'KT19'),
#  Text(19, 0, 'KT20'),
#  Text(20, 0, 'KT21'),
#  Text(21, 0, 'KT22'),
#  Text(22, 0, 'KT23'),
#  Text(23, 0, 'KT24')]

# %%
plt.figure(figsize=(15,10))
ax = sns.boxplot(x='Postcode', y='Price/Bedroom', data=df, order = x_order)
ax.set_xticklabels(ax.get_xticklabels(), rotation=50, ha="right")
ax.tick_params(labelsize=13)
# Out:
# [Text(0, 0, 'KT1'),
#  Text(1, 0, 'KT2'),
#  Text(2, 0, 'KT3'),
#  Text(3, 0, 'KT4'),
#  Text(4, 0, 'KT5'),
#  Text(5, 0, 'KT6'),
#  Text(6, 0, 'KT7'),
#  Text(7, 0, 'KT8'),
#  Text(8, 0, 'KT9'),
#  Text(9, 0, 'KT10'),
#  Text(10, 0, 'KT11'),
#  Text(11, 0, 'KT12'),
#  Text(12, 0, 'KT13'),
#  Text(13, 0, 'KT14'),
#  Text(14, 0, 'KT15'),
#  Text(15, 0, 'KT16'),
#  Text(16, 0, 'TK17'),
#  Text(17, 0, 'KT18'),
#  Text(18, 0, 'KT19'),
#  Text(19, 0, 'KT20'),
#  Text(20, 0, 'KT21'),
#  Text(21, 0, 'KT22'),
#  Text(22, 0, 'KT23'),
#  Text(23, 0, 'KT24')]
