# %%
#Import libraries

import pandas as pd
import json
import requests # library to handle requests
from requests import get
import re # Regular expression
import ast

from itertools import islice
from geopy.geocoders import Nominatim

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

from bs4 import BeautifulSoup

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ___

# %% [markdown]
# ### 1. Scrape data from online

# %%
#1.#https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%5E972&maxBedrooms=5&maxPrice=800000&minPrice=350000&index=24&propertyTypes=&includeSSTC=false&mustHave=&dontShow=newHome%2CsharedOwnership%2Cretirement&furnishTypes=&keywords=

#2#https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%5E94441&maxPrice=1000000&minPrice=300000&index=24&propertyTypes=detached%2Cflat%2Csemi-detached%2Cterraced&secondaryDisplayPropertyType=housesandflats&includeSSTC=false&mustHave=&dontShow=retirement&furnishTypes=&keywords=

#KT area: https://en.wikipedia.org/wiki/KT_postcode_area

all_data = pd.DataFrame([])

base_url= ("https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%5E94441&maxPrice=1000000&minPrice=300000&index=24&propertyTypes=detached%2Cflat%2Csemi-detached%2Cterraced&secondaryDisplayPropertyType=housesandflats&includeSSTC=false&mustHave=&dontShow=retirement&furnishTypes=&keywords=")

results = requests.get(base_url).text
soup = BeautifulSoup(results, "html.parser")

find = soup.find_all("script")

reg = r"window.jsonModel\s+=\s+(\{.*?\</script>)"

pattern = re.compile(reg)
match = pattern.findall(str(find))

match_strip = match[0].rstrip("</script>")

s1 = json.dumps(match_strip)
json_data = json.loads(s1) 

s3 = json.loads(str(json_data))

pagination =  s3.get("pagination").get("options")

pagination = pd.DataFrame(pagination)



for value in islice(pagination.iloc[:,0],0,5):
    print(value)

    iter_url = "https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%5E94441&maxPrice=1000000&minPrice=300000&index={}&propertyTypes=detached%2Cflat%2Csemi-detached%2Cterraced&secondaryDisplayPropertyType=housesandflats&includeSSTC=false&mustHave=&dontShow=retirement&furnishTypes=&keywords=".format(value)
    
   
   
    results = requests.get(iter_url).text
    soup = BeautifulSoup(results, "html.parser")
    
    find = soup.find_all("script")
    
    reg = r"window.jsonModel\s+=\s+(\{.*?\</script>)"

    pattern = re.compile(reg)
    match = pattern.findall(str(find))

    match_strip = match[0].rstrip("</script>")

    s1 = json.dumps(match_strip)
    json_data = json.loads(s1) 

    s3 = json.loads(str(json_data))
    
    list =  s3.get("properties")
    
    df = pd.DataFrame(list)
    df.drop(["propertyImages"], axis=1, inplace=True)

    all_data = all_data.append(df, ignore_index=True)
    
    
    
    
pd.set_option("display.max_rows", df.shape[0]+1)


all_data.shape
all_data
# Out:
# 0
# 24
# 48
# 72
# 96
#             id  bedrooms  bathrooms  numberOfImages  numberOfFloorplans  \
# 0     89364007         3        2.0              17                   2
# 1     72598905         4        2.0              22                   1
# 2     86007409         4        2.0              12                   1
# 3     73644852         4        3.0              29                   1
# 4     88981993         4        2.0              14                   1
# ..         ...       ...        ...             ...                 ...
# 120   88613542         3        1.0              10                   1
# 121  102080669         4        3.0              21                   1
# 122  100675610         4        2.0              27                   1
# 123   93305567         4        NaN              16                   1
# 124   78137367         3        2.0               7                   1
#
#      numberOfVirtualTours  \
# 0                       0
# 1                       1
# 2                       0
# 3                       1
# 4                       1
# ..                    ...
# 120                     0
# 121                     0
# 122                     0
# 123                     0
# 124                     0
#
#                                                                                                                                                                                                                                                                                                           summary  \
# 0    Forming part of a former school founded by Sir Edward Colebrooke in 1870 and converted by Messrs Astral Homes in 1986 is this stunning split-level home, offered to the market in excellent condition throughout. The ground floor is a wonderful space, that flows very well with a large modern fitted ...
# 1                                                                                     *VIEWINGS BY APPOINTMENT FROM SATURDAY 13TH MARCH* A modern four bedroom, two bathroom, detached family home in excellent condition, with plenty of parking and within the catchment of Hinchley Wood School. EPC rating C.
# 2                                                                                                                                                             Situated in a secluded position within close proximity of Hinchley Wood School and train station is this deceptively spacious detached family home!
# 3     Rare opportunity to acquire this wonderful detached family home arranged over three floors with five double bedrooms. Situated on a very desirable residential road in New Malden and offering easy access to New Malden station, the local high street and within the catchment of excellent local schools
# 4          A newly constructed 4 bedroom detached house offering a delightful rear garden, excellent specification and situated in a popular semi rural location. Originally constructed in 2020 this beautifully presented home offers extremely light, bright and contemporary accommodation.  Currently thi...
# ..                                                                                                                                                                                                                                                                                                            ...
# 120                                                                                                                                          A detached Victorian villa with basement, off street parking for two cars and signifcant potential to extend both into the loft and on the ground floor to the rear.
# 121           Located on Ruxbury Road, at the foot of St. Ann's Hill is this secluded detached home. The current owners have extended and renovated to create a lovely family home. Accommodation consists of four double bedrooms, three of which have en-suite facilities, there are three reception rooms, ...
# 122  Ivy Gate are extremely proud to offer to the market this beautifully presented four bedroom detached family home overlooking one of the ponds on this prestigious private development. The property comprises; wide entrance hallway, ground floor W/C, leading through to the formal dining room on the ...
# 123  We are delighted to offer for sale this four double bedroom, detached family home enjoying an enviable position in a quiet cul-de-sac, yet ideally placed for Weybridge town centre with its wealth of shops, restaurants and cafes. The Queens Road and Oatlands Village are also within easy reach as is W
# 124                                                                                                                                                                                                                                                                            Beautifully presented period home.
#
#                                  displayAddress countryCode  \
# 0                       Ottershaw, Surrey, KT16          GB
# 1              Soprano Way, Hinchley Wood, KT10          GB
# 2                       Couchmore Avenue, Esher          GB
# 3                    Cavendish Road, New Malden          GB
# 4                                   Chessington          GB
# ..                                          ...         ...
# 120       Kings Road, Kingston upon Thames, KT2          GB
# 121                      Ruxbury Road, Chertsey          GB
# 122         Beaumont Drive, Worcester Park, KT4          GB
# 123  Marlborough Drive, Weybridge, Surrey, KT13          GB
# 124            Wolsey Road, Esher, Surrey, KT10          GB
#
#                                             location  ...  \
# 0     {'latitude': 51.358761, 'longitude': -0.53557}  ...
# 1      {'latitude': 51.3753, 'longitude': -0.326284}  ...
# 2      {'latitude': 51.3791, 'longitude': -0.342057}  ...
# 3     {'latitude': 51.397959, 'longitude': -0.25357}  ...
# 4    {'latitude': 51.355801, 'longitude': -0.300656}  ...
# ..                                               ...  ...
# 120  {'latitude': 51.417653, 'longitude': -0.300204}  ...
# 121  {'latitude': 51.392951, 'longitude': -0.522183}  ...
# 122  {'latitude': 51.383701, 'longitude': -0.236638}  ...
# 123    {'latitude': 51.37457, 'longitude': -0.44701}  ...
# 124  {'latitude': 51.369089, 'longitude': -0.368106}  ...
#
#     onlineViewingsAvailable            heading  enhancedListing  \
# 0                     False  Featured Property            False
# 1                     False                               False
# 2                      True                               False
# 3                      True                               False
# 4                     False                               False
# ..                      ...                ...              ...
# 120                   False                               False
# 121                   False                               False
# 122                   False                               False
# 123                   False                               False
# 124                   False                               False
#
#                  propertyTypeFullDescription displayStatus  \
# 0    3 bedroom end of terrace house for sale
# 1          4 bedroom detached house for sale
# 2          4 bedroom detached house for sale
# 3          4 bedroom detached house for sale
# 4          4 bedroom detached house for sale
# ..                                       ...           ...
# 120        3 bedroom detached house for sale
# 121        4 bedroom detached house for sale
# 122        4 bedroom detached house for sale
# 123        4 bedroom detached house for sale
# 124        3 bedroom detached house for sale
#
#                            formattedBranchName         addedOrReduced  \
# 0                         by Hodders, Chertsey    Added on 25/02/2021
# 1             by Curchods Estate Agents, Esher  Reduced on 27/02/2021
# 2                  by Barnard Marcus, Surbiton    Added on 22/10/2020
# 3             by SeOUL Residential, New Malden  Reduced on 23/12/2020
# 4     by Henshaws Estate Agents, Great Bookham    Added on 10/02/2021
# ..                                         ...                    ...
# 120            by Featherstone Leigh, Kingston    Added on 26/01/2021
# 121              by Newboulds & Co, Shepperton    Added on 18/01/2021
# 122     by Ivy Gate, London - Sales & Lettings    Added on 12/11/2020
# 123        by Martin Flashman & Co., Weybridge  Reduced on 04/09/2020
# 124                          by Savills, Esher    Added on 21/02/2021
#
#     isRecent formattedDistance  hasBrandPlus
# 0      False                            True
# 1      False                            True
# 2      False                            True
# 3      False                            True
# 4      False                            True
# ..       ...               ...           ...
# 120    False                            True
# 121    False                            True
# 122    False                            True
# 123    False                            True
# 124    False                            True
#
# [125 rows x 47 columns]
